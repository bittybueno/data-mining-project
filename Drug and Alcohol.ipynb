# %%
import pandas as pd 
from datetime import datetime, date, time, timedelta

 
df = pd.read_csv("crime.csv") 
df.head()
# Out:
#    INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0   2016376978   2016376978521300          5213                       0
# 1  20186000994  20186000994239900          2399                       0
# 2  20166003953  20166003953230500          2305                       0
# 3    201872333    201872333239900          2399                       0
# 4   2017411405   2017411405230300          2303                       0
#
#                 OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0  weapon-unlawful-discharge-of          all-other-crimes
# 1                   theft-other                   larceny
# 2      theft-items-from-vehicle  theft-from-motor-vehicle
# 3                   theft-other                   larceny
# 4                theft-shoplift                   larceny
#
#     FIRST_OCCURRENCE_DATE   LAST_OCCURRENCE_DATE          REPORTED_DATE  \
# 0   6/15/2016 11:31:00 PM                    NaN  6/15/2016 11:31:00 PM
# 1  10/11/2017 12:30:00 PM  10/11/2017 4:55:00 PM   1/29/2018 5:53:00 PM
# 2     3/4/2016 8:00:00 PM   4/25/2016 8:00:00 AM   4/26/2016 9:02:00 PM
# 3    1/30/2018 7:20:00 PM                    NaN  1/30/2018 10:29:00 PM
# 4    6/22/2017 8:53:00 PM                    NaN   6/23/2017 4:09:00 PM
#
#       INCIDENT_ADDRESS      GEO_X      GEO_Y     GEO_LON    GEO_LAT  \
# 0                  NaN  3193983.0  1707251.0 -104.809881  39.773188
# 1                  NaN  3201943.0  1711852.0 -104.781434  39.785649
# 2  2932 S JOSEPHINE ST  3152762.0  1667011.0 -104.957381  39.663490
# 3  705 S COLORADO BLVD  3157162.0  1681320.0 -104.941440  39.702698
# 4       2810 E 1ST AVE  3153211.0  1686545.0 -104.955370  39.717107
#
#    DISTRICT_ID  PRECINCT_ID             NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# 0            5          521                   montbello         1           0
# 1            5          522  gateway-green-valley-ranch         1           0
# 2            3          314                   wellshire         1           0
# 3            3          312                     belcaro         1           0
# 4            3          311                cherry-creek         1           0

# %%
df['DATE'], df['TIME'] = df['FIRST_OCCURRENCE_DATE'].str.split(' ', 1).str


df['DATE'] = pd.to_datetime(df['DATE'])
df['day_of_week'] = df['DATE'].dt.day_name()
df
# Out:
#         INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0        2016376978   2016376978521300          5213                       0
# 1       20186000994  20186000994239900          2399                       0
# 2       20166003953  20166003953230500          2305                       0
# 3         201872333    201872333239900          2399                       0
# 4        2017411405   2017411405230300          2303                       0
# ...             ...                ...           ...                     ...
# 526095   2019688353   2019688353121200          1212                       0
# 526096   2019688368   2019688368540100          5401                       0
# 526097   2019688404   2019688404131302          1313                       2
# 526098   2019688441   2019688441131302          1313                       2
# 526099   2019688475   2019688475220300          2203                       0
#
#                      OFFENSE_TYPE_ID           OFFENSE_CATEGORY_ID  \
# 0       weapon-unlawful-discharge-of              all-other-crimes
# 1                        theft-other                       larceny
# 2           theft-items-from-vehicle      theft-from-motor-vehicle
# 3                        theft-other                       larceny
# 4                     theft-shoplift                       larceny
# ...                              ...                           ...
# 526095           robbery-car-jacking                       robbery
# 526096  traffic-accident-hit-and-run              traffic-accident
# 526097                    assault-dv  other-crimes-against-persons
# 526098                    assault-dv  other-crimes-against-persons
# 526099    burglary-business-by-force                      burglary
#
#          FIRST_OCCURRENCE_DATE   LAST_OCCURRENCE_DATE           REPORTED_DATE  \
# 0        6/15/2016 11:31:00 PM                    NaN   6/15/2016 11:31:00 PM
# 1       10/11/2017 12:30:00 PM  10/11/2017 4:55:00 PM    1/29/2018 5:53:00 PM
# 2          3/4/2016 8:00:00 PM   4/25/2016 8:00:00 AM    4/26/2016 9:02:00 PM
# 3         1/30/2018 7:20:00 PM                    NaN   1/30/2018 10:29:00 PM
# 4         6/22/2017 8:53:00 PM                    NaN    6/23/2017 4:09:00 PM
# ...                        ...                    ...                     ...
# 526095  10/27/2019 11:45:00 PM                    NaN  10/28/2019 12:08:00 AM
# 526096  10/28/2019 12:20:00 AM                    NaN  10/28/2019 12:35:00 AM
# 526097   10/28/2019 1:13:00 AM                    NaN   10/28/2019 3:26:00 AM
# 526098   10/28/2019 2:10:00 AM                    NaN   10/28/2019 4:25:00 AM
# 526099   10/28/2019 2:50:00 AM  10/28/2019 3:10:00 AM   10/28/2019 3:43:00 AM
#
#                  INCIDENT_ADDRESS  ...     GEO_LON    GEO_LAT  DISTRICT_ID  \
# 0                             NaN  ... -104.809881  39.773188            5
# 1                             NaN  ... -104.781434  39.785649            5
# 2             2932 S JOSEPHINE ST  ... -104.957381  39.663490            3
# 3             705 S COLORADO BLVD  ... -104.941440  39.702698            3
# 4                  2810 E 1ST AVE  ... -104.955370  39.717107            3
# ...                           ...  ...         ...        ...          ...
# 526095  E COLFAX AVE / N XENIA ST  ... -104.885821  39.740155            2
# 526096         1959 S BROADWAY ST  ... -104.987794  39.681001            3
# 526097            7030 N TOWER RD  ... -104.770112  39.824869            5
# 526098         3831 N SHOSHONE ST  ... -105.009777  39.769921            1
# 526099       4797 S WADSWORTH WAY  ... -105.087432  39.630572            4
#
#         PRECINCT_ID             NEIGHBORHOOD_ID  IS_CRIME IS_TRAFFIC  \
# 0               521                   montbello         1          0
# 1               522  gateway-green-valley-ranch         1          0
# 2               314                   wellshire         1          0
# 3               312                     belcaro         1          0
# 4               311                cherry-creek         1          0
# ...             ...                         ...       ...        ...
# 526095          223                 east-colfax         1          0
# 526096          313                    overland         0          1
# 526097          522                         dia         1          0
# 526098          111                   sunnyside         1          0
# 526099          423                     marston         1          0
#
#              DATE         TIME day_of_week
# 0      2016-06-15  11:31:00 PM   Wednesday
# 1      2017-10-11  12:30:00 PM   Wednesday
# 2      2016-03-04   8:00:00 PM      Friday
# 3      2018-01-30   7:20:00 PM     Tuesday
# 4      2017-06-22   8:53:00 PM    Thursday
# ...           ...          ...         ...
# 526095 2019-10-27  11:45:00 PM      Sunday
# 526096 2019-10-28  12:20:00 AM      Monday
# 526097 2019-10-28   1:13:00 AM      Monday
# 526098 2019-10-28   2:10:00 AM      Monday
# 526099 2019-10-28   2:50:00 AM      Monday
#
# [526100 rows x 22 columns]

# %%
df_DA = df[['OFFENSE_CATEGORY_ID', 'TIME', 'day_of_week','NEIGHBORHOOD_ID','GEO_LAT','GEO_LON']]
df_DA = df_DA.loc[df_DA.OFFENSE_CATEGORY_ID == 'drug-alcohol']
df_DA_am =  df_DA.loc[df_DA.TIME.str[-2:] == "AM" ]
df_DA_am['TIME'] = [x[:-3] for x in df_DA_am['TIME']]
df_DA_am['TIME'] =  pd.to_datetime(df_DA_am['TIME'], format='%H:%M:%S')
# df_DA_am['TIME'] = [d.time() for d in df_DA_am['TIME']]
df_DA_am
# Out:
# /Users/missybueno/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/missybueno/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#        OFFENSE_CATEGORY_ID                TIME day_of_week  \
# 99            drug-alcohol 1900-01-01 12:51:00   Wednesday
# 208           drug-alcohol 1900-01-01 07:00:00   Wednesday
# 378           drug-alcohol 1900-01-01 11:00:00   Wednesday
# 433           drug-alcohol 1900-01-01 02:14:00   Wednesday
# 494           drug-alcohol 1900-01-01 02:14:00   Wednesday
# ...                    ...                 ...         ...
# 525573        drug-alcohol 1900-01-01 12:52:00      Friday
# 525736        drug-alcohol 1900-01-01 10:31:00      Sunday
# 525851        drug-alcohol 1900-01-01 11:00:00    Thursday
# 525893        drug-alcohol 1900-01-01 01:12:00     Tuesday
# 525958        drug-alcohol 1900-01-01 06:00:00   Wednesday
#
#                   NEIGHBORHOOD_ID    GEO_LAT     GEO_LON
# 99                    east-colfax  39.740157 -104.884651
# 208                     sunnyside  39.774280 -105.010860
# 378                      highland  39.759878 -105.022905
# 433                     sunnyside  39.779019 -105.006447
# 494                     sunnyside  39.779019 -105.006447
# ...                           ...        ...         ...
# 525573  college-view-south-platte  39.678657 -105.020370
# 525736                  stapleton  39.783613 -104.895026
# 525851                five-points  39.748084 -104.977538
# 525893                 platt-park  39.680331 -104.973417
# 525958                east-colfax  39.738855 -104.897254
#
# [9074 rows x 6 columns]

# %%
df_DA = df_DA[['OFFENSE_CATEGORY_ID', 'TIME', 'day_of_week','NEIGHBORHOOD_ID','GEO_LAT','GEO_LON']]
df_DA = df_DA.loc[df_DA.OFFENSE_CATEGORY_ID == 'drug-alcohol']
df_DA_pm =  df_DA.loc[df_DA.TIME.str[-2:] == "PM" ]
df_DA_pm['TIME'] = [x[:-3] for x in df_DA_pm['TIME']]
df_DA_pm['TIME'] =  pd.to_datetime(df_DA_pm['TIME'], format='%H:%M:%S')
df_DA_pm['TIME'] = df_DA_pm['TIME'] + timedelta(hours=12)
# df_DA_pm['TIME'] = [d.time() for d in df_DA_pm['TIME']]
df_DA_pm
# Out:
# /Users/missybueno/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/missybueno/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/missybueno/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        OFFENSE_CATEGORY_ID                TIME day_of_week  \
# 10            drug-alcohol 1900-01-01 20:04:00     Tuesday
# 34            drug-alcohol 1900-01-01 18:19:00     Tuesday
# 60            drug-alcohol 1900-01-01 17:00:00      Friday
# 76            drug-alcohol 1900-01-01 22:46:00     Tuesday
# 107           drug-alcohol 1900-01-01 19:44:00     Tuesday
# ...                    ...                 ...         ...
# 526048        drug-alcohol 1900-01-01 23:44:00      Friday
# 526071        drug-alcohol 1900-01-01 15:47:00      Sunday
# 526073        drug-alcohol 1900-01-01 16:25:00      Sunday
# 526074        drug-alcohol 1900-01-01 17:39:00      Sunday
# 526077        drug-alcohol 1900-01-01 17:56:00      Sunday
#
#             NEIGHBORHOOD_ID    GEO_LAT     GEO_LON
# 10                goldsmith  39.678463 -104.925197
# 34             lincoln-park  39.729096 -104.992773
# 60             lincoln-park  39.739407 -105.016299
# 76      northeast-park-hill  39.772877 -104.940550
# 107      north-capitol-hill  39.740844 -104.979815
# ...                     ...        ...         ...
# 526048         capitol-hill  39.728572 -104.979138
# 526071       jefferson-park  39.756634 -105.019100
# 526073            city-park  39.740473 -104.951818
# 526074                baker  39.710639 -104.988882
# 526077          five-points  39.751237 -104.985866
#
# [25328 rows x 6 columns]

# %%
final_DA = pd.concat([df_DA_am, df_DA_pm], ignore_index=True, sort =False)

block1 = '09/19/18 04:00:00'
block2 = '09/19/18 08:00:00'
block3 = '09/19/18 12:00:00'
block4 = '09/19/18 16:00:00'
block5 = '09/19/18 20:00:00'
block6 = '09/19/18 23:59:00'
datetime_object1 = datetime.strptime(block1, '%m/%d/%y %H:%M:%S')
datetime_object2 = datetime.strptime(block2, '%m/%d/%y %H:%M:%S')
datetime_object3 = datetime.strptime(block3, '%m/%d/%y %H:%M:%S')
datetime_object4 = datetime.strptime(block4, '%m/%d/%y %H:%M:%S')
datetime_object5 = datetime.strptime(block5, '%m/%d/%y %H:%M:%S')
datetime_object6 = datetime.strptime(block6, '%m/%d/%y %H:%M:%S')

# %%
final_DA.loc[final_DA['TIME'].dt.time <= datetime_object1.time(), 'TIME'] = datetime_object1

final_DA.loc[(final_DA['TIME'].dt.time > datetime_object1.time())&(final_DA['TIME'].dt.time <= datetime_object2.time()), 'TIME'] = datetime_object2

final_DA.loc[(final_DA['TIME'].dt.time > datetime_object2.time())&(final_DA['TIME'].dt.time <= datetime_object3.time()), 'TIME'] = datetime_object3

final_DA.loc[(final_DA['TIME'].dt.time > datetime_object3.time())&(final_DA['TIME'].dt.time <= datetime_object4.time()), 'TIME'] = datetime_object4

final_DA.loc[(final_DA['TIME'].dt.time > datetime_object4.time())&(final_DA['TIME'].dt.time <= datetime_object5.time()), 'TIME'] = datetime_object5

final_DA.loc[(final_DA['TIME'].dt.time > datetime_object5.time())&(final_DA['TIME'].dt.time <= datetime_object6.time()), 'TIME'] = datetime_object6



final_DA['TIME'] = [d.time() for d in final_DA['TIME']]
final_DA
# Out:
#       OFFENSE_CATEGORY_ID      TIME day_of_week NEIGHBORHOOD_ID    GEO_LAT  \
# 0            drug-alcohol  16:00:00   Wednesday     east-colfax  39.740157
# 1            drug-alcohol  08:00:00   Wednesday       sunnyside  39.774280
# 2            drug-alcohol  12:00:00   Wednesday        highland  39.759878
# 3            drug-alcohol  04:00:00   Wednesday       sunnyside  39.779019
# 4            drug-alcohol  04:00:00   Wednesday       sunnyside  39.779019
# ...                   ...       ...         ...             ...        ...
# 34397        drug-alcohol  23:59:00      Friday    capitol-hill  39.728572
# 34398        drug-alcohol  16:00:00      Sunday  jefferson-park  39.756634
# 34399        drug-alcohol  20:00:00      Sunday       city-park  39.740473
# 34400        drug-alcohol  20:00:00      Sunday           baker  39.710639
# 34401        drug-alcohol  20:00:00      Sunday     five-points  39.751237
#
#           GEO_LON
# 0     -104.884651
# 1     -105.010860
# 2     -105.022905
# 3     -105.006447
# 4     -105.006447
# ...           ...
# 34397 -104.979138
# 34398 -105.019100
# 34399 -104.951818
# 34400 -104.988882
# 34401 -104.985866
#
# [34402 rows x 6 columns]

# %%
DA_csv = final_DA[['day_of_week','NEIGHBORHOOD_ID', 'TIME']]
DA_plot = final_DA[['day_of_week','NEIGHBORHOOD_ID', 'TIME','GEO_LAT','GEO_LON']]
DA_csv = DA_csv.sample(5000)
DA_csv.to_csv('DA.csv')
DA_plot.to_csv('DA_Plot.csv')


# !python apriori.py -f 'DA.csv' -s 0.0015
# Out:
# item: ('highland', '16:00:00') , 0.002
# item: ('harvey-park', 'Friday') , 0.002
# item: ('auraria', 'Friday') , 0.002
# item: ('university-hills', 'Thursday') , 0.002
# item: ('chaffee-park', 'Tuesday') , 0.002
# item: ('23:59:00', 'barnum') , 0.002
# item: ('ruby-hill', 'Monday') , 0.002
# item: ('sunnyside', 'Friday') , 0.002
# item: ('Sunday', 'union-station') , 0.002
# item: ('union-station', 'Tuesday') , 0.002
# item: ('valverde', '20:00:00') , 0.002
# item: ('Friday', 'barnum-west') , 0.002
# item: ('16:00:00', 'goldsmith') , 0.002
# item: ('jefferson-park', 'Monday') , 0.002
# item: ('23:59:00', 'college-view-south-platte') , 0.002
# item: ('hampden-south', 'Tuesday') , 0.002
# item: ('city-park', '12:00:00') , 0.002
# item: ('12:00:00', 'sun-valley') , 0.002
# item: ('jefferson-park', '12:00:00') , 0.002
# item: ('goldsmith', 'Wednesday') , 0.002
# item: ('Saturday', 'mar-lee') , 0.002
# item: ('overland', '20:00:00') , 0.002
# item: ('virginia-village', 'Monday') , 0.002
# item: ('sunnyside', '04:00:00') , 0.002
# item: ('overland', 'Thursday') , 0.002
# item: ('Saturday', 'globeville') , 0.002
# item: ('overland', '04:00:00') , 0.002
# item: ('gateway-green-valley-ranch', '20:00:00') , 0.002
# item: ('villa-park', '12:00:00') , 0.002
# item: ('Thursday', 'elyria-swansea') , 0.002
# item: ('sunnyside', '23:59:00') , 0.002
# item: ('Monday', 'barnum-west') , 0.002
# item: ('23:59:00', 'five-points', 'Tuesday') , 0.002
# item: ('Saturday', '16:00:00', 'civic-center') , 0.002
# item: ('baker', '20:00:00', 'Friday') , 0.002
# item: ('Wednesday', '12:00:00', 'lincoln-park') , 0.002
# item: ('Saturday', '04:00:00', 'east-colfax') , 0.002
# item: ('five-points', '12:00:00', 'Friday') , 0.002
# item: ('12:00:00', 'Wednesday', 'cbd') , 0.002
# item: ('five-points', '12:00:00', 'Wednesday') , 0.002
# item: ('16:00:00', 'westwood', 'Tuesday') , 0.002
# item: ('12:00:00', 'Wednesday', 'capitol-hill') , 0.002
# item: ('12:00:00', 'Monday', 'civic-center') , 0.002
# item: ('Thursday', '12:00:00', 'capitol-hill') , 0.002
# item: ('16:00:00', 'lincoln-park', 'Friday') , 0.002
# item: ('west-colfax', '16:00:00', 'Monday') , 0.002
# item: ('16:00:00', 'Friday', 'cbd') , 0.002
# item: ('Tuesday', '16:00:00', 'barnum-west') , 0.002
# item: ('Wednesday', '12:00:00', 'civic-center') , 0.002
# item: ('Thursday', '12:00:00', 'lincoln-park') , 0.002
# item: ('west-colfax', 'Thursday', '16:00:00') , 0.002
# item: ('Sunday', '16:00:00', 'five-points') , 0.002
# item: ('Saturday', '16:00:00', 'capitol-hill') , 0.002
# item: ('athmar-park', '16:00:00', 'Friday') , 0.002
# item: ('university-hills', '20:00:00') , 0.002
# item: ('cole', '04:00:00') , 0.002
# item: ('16:00:00', 'bear-valley') , 0.002
# item: ('barnum', '20:00:00') , 0.002
# item: ('16:00:00', 'speer') , 0.002
# item: ('Sunday', 'west-highland') , 0.002
# item: ('Monday', 'speer') , 0.002
# item: ('23:59:00', 'stapleton') , 0.002
# item: ('westwood', 'Monday') , 0.002
# item: ('dia', '20:00:00') , 0.002
# item: ('cole', 'Tuesday') , 0.002
# item: ('dia', 'Friday') , 0.002
# item: ('virginia-village', 'Wednesday') , 0.002
# item: ('dia', '12:00:00') , 0.002
# item: ('regis', 'Friday') , 0.002
# item: ('Wednesday', 'union-station') , 0.002
# item: ('baker', '12:00:00') , 0.002
# item: ('23:59:00', 'goldsmith') , 0.002
# item: ('Sunday', 'westwood') , 0.002
# item: ('16:00:00', 'whittier') , 0.002
# item: ('Sunday', 'cole') , 0.002
# item: ('12:00:00', 'mar-lee') , 0.002
# item: ('04:00:00', 'montbello') , 0.002
# item: ('washington-park', '12:00:00') , 0.002
# item: ('08:00:00', 'capitol-hill') , 0.002
# item: ('valverde', '16:00:00') , 0.002
# item: ('Thursday', 'northeast-park-hill') , 0.002
# item: ('baker', '04:00:00') , 0.002
# item: ('20:00:00', 'barnum-west') , 0.002
# item: ('ruby-hill', '20:00:00') , 0.002
# item: ('harvey-park-south', '12:00:00') , 0.002
# item: ('ruby-hill', 'Wednesday') , 0.002
# item: ('23:59:00', 'ruby-hill') , 0.002
# item: ('regis', '04:00:00') , 0.002
# item: ('sunnyside', 'Tuesday') , 0.002
# item: ('stapleton', '12:00:00', 'Wednesday') , 0.002
# item: ('16:00:00', 'Monday', 'cbd') , 0.002
# item: ('Friday', '16:00:00', 'east-colfax') , 0.002
# item: ('stapleton', '12:00:00', 'Monday') , 0.002
# item: ('Friday', '12:00:00', 'east-colfax') , 0.002
# item: ('Sunday', '20:00:00', 'civic-center') , 0.002
# item: ('cheesman-park', '16:00:00', 'Friday') , 0.002
# item: ('Sunday', '20:00:00', 'cbd') , 0.002
# item: ('Thursday', '16:00:00', 'civic-center') , 0.002
# item: ('east-colfax', '04:00:00', 'Wednesday') , 0.002
# item: ('Friday', '20:00:00', 'civic-center') , 0.002
# item: ('city-park-west', '20:00:00', 'Tuesday') , 0.002
# item: ('16:00:00', 'north-capitol-hill', 'Tuesday') , 0.002
# item: ('Sunday', '16:00:00', 'cbd') , 0.002
# item: ('mar-lee', 'Friday') , 0.002
# item: ('university-hills', 'Tuesday') , 0.002
# item: ('12:00:00', 'bear-valley') , 0.002
# item: ('elyria-swansea', 'Wednesday') , 0.002
# item: ('Thursday', 'mar-lee') , 0.002
# item: ('barnum', '04:00:00') , 0.002
# item: ('16:00:00', 'gateway-green-valley-ranch') , 0.002
# item: ('university-hills', '04:00:00') , 0.002
# item: ('ruby-hill', '04:00:00') , 0.002
# item: ('Saturday', 'union-station') , 0.002
# item: ('Sunday', 'stapleton') , 0.002
# item: ('ruby-hill', 'Tuesday') , 0.002
# item: ('sunnyside', '20:00:00') , 0.002
# item: ('valverde', 'Tuesday') , 0.002
# item: ('college-view-south-platte', 'Friday') , 0.002
# item: ('Thursday', 'jefferson-park') , 0.002
# item: ('16:00:00', 'virginia-village') , 0.002
# item: ('harvey-park-south', '16:00:00') , 0.002
# item: ('23:59:00', 'speer') , 0.002
# item: ('washington-virginia-vale', 'Wednesday') , 0.002
# item: ('jefferson-park', '16:00:00') , 0.002
# item: ('20:00:00', 'Friday', 'cbd') , 0.002
# item: ('23:59:00', 'Saturday', 'capitol-hill') , 0.002
# item: ('12:00:00', 'east-colfax', 'Tuesday') , 0.002
# item: ('23:59:00', 'Monday', 'east-colfax') , 0.002
# item: ('23:59:00', 'Thursday', 'capitol-hill') , 0.002
# item: ('20:00:00', 'Friday', 'city-park-west') , 0.002
# item: ('23:59:00', 'Thursday', 'cbd') , 0.002
# item: ('23:59:00', 'Friday', 'east-colfax') , 0.002
# item: ('23:59:00', 'Friday', 'cbd') , 0.002
# item: ('Saturday', '20:00:00', 'north-capitol-hill') , 0.002
# item: ('20:00:00', 'Monday', 'cbd') , 0.002
# item: ('23:59:00', 'east-colfax', 'Tuesday') , 0.002
# item: ('Friday', '20:00:00', 'north-capitol-hill') , 0.002
# item: ('Sunday', '16:00:00', 'east-colfax') , 0.002
# item: ('Friday', '04:00:00', 'east-colfax') , 0.002
# item: ('Sunday', 'baker') , 0.002
# item: ('overland', 'Wednesday') , 0.002
# item: ('08:00:00', 'civic-center') , 0.002
# item: ('Thursday', 'cole') , 0.002
# item: ('23:59:00', 'mar-lee') , 0.002
# item: ('west-colfax', 'Tuesday') , 0.002
# item: ('villa-park', 'Wednesday') , 0.002
# item: ('baker', 'Monday') , 0.002
# item: ('villa-park', 'Friday') , 0.002
# item: ('cole', 'Wednesday') , 0.002
# item: ('regis', '16:00:00') , 0.002
# item: ('Wednesday', 'barnum-west') , 0.002
# item: ('washington-virginia-vale', '20:00:00') , 0.002
# item: ('23:59:00', 'sun-valley') , 0.002
# item: ('harvey-park', '16:00:00') , 0.002
# item: ('college-view-south-platte', 'Wednesday') , 0.002
# item: ('auraria', 'Wednesday') , 0.002
# item: ('20:00:00', 'hampden-south') , 0.002
# item: ('virginia-village', '20:00:00') , 0.002
# item: ('overland', '16:00:00') , 0.002
# item: ('auraria', '20:00:00') , 0.002
# item: ('23:59:00', 'city-park-west') , 0.002
# item: ('gateway-green-valley-ranch', 'Friday') , 0.002
# item: ('20:00:00', 'northeast-park-hill') , 0.002
# item: ('23:59:00', 'washington-virginia-vale') , 0.002
# item: ('08:00:00', 'cbd') , 0.002
# item: ('villa-park', 'Tuesday') , 0.002
# item: ('villa-park', '04:00:00') , 0.002
# item: ('globeville', 'Friday') , 0.002
# item: ('04:00:00', 'union-station') , 0.002
# item: ('Saturday', '20:00:00', 'cbd') , 0.002
# item: ('Monday', '12:00:00', 'east-colfax') , 0.002
# item: ('20:00:00', 'Monday', 'east-colfax') , 0.002
# item: ('athmar-park', '16:00:00', 'Tuesday') , 0.002
# item: ('23:59:00', 'Wednesday', 'capitol-hill') , 0.002
# item: ('Saturday', '16:00:00', 'five-points') , 0.002
# item: ('northeast-park-hill', 'Wednesday') , 0.002
# item: ('auraria', '12:00:00') , 0.002
# item: ('Friday', 'montbello') , 0.002
# item: ('08:00:00', 'east-colfax') , 0.002
# item: ('20:00:00', 'sun-valley') , 0.002
# item: ('berkeley', '16:00:00') , 0.002
# item: ('five-points', '08:00:00') , 0.002
# item: ('Thursday', 'union-station') , 0.002
# item: ('globeville', '04:00:00') , 0.002
# item: ('villa-park', 'Thursday') , 0.002
# item: ('12:00:00', 'globeville') , 0.002
# item: ('cole', 'Friday') , 0.002
# item: ('barnum-west', 'Tuesday') , 0.002
# item: ('16:00:00', 'barnum') , 0.002
# item: ('20:00:00', 'mar-lee') , 0.002
# item: ('23:59:00', 'overland') , 0.002
# item: ('globeville', 'Wednesday') , 0.002
# item: ('westwood', 'Wednesday') , 0.002
# item: ('chaffee-park', '16:00:00') , 0.002
# item: ('highland', '20:00:00') , 0.002
# item: ('Thursday', 'ruby-hill') , 0.002
# item: ('Thursday', 'globeville') , 0.002
# item: ('20:00:00', 'Wednesday', 'city-park-west') , 0.002
# item: ('Thursday', '12:00:00', 'east-colfax') , 0.002
# item: ('capitol-hill', '12:00:00', 'Tuesday') , 0.002
# item: ('20:00:00', 'Monday', 'city-park-west') , 0.002
# item: ('16:00:00', 'union-station') , 0.003
# item: ('university-hills', 'Friday') , 0.003
# item: ('athmar-park', '04:00:00') , 0.003
# item: ('Thursday', 'barnum') , 0.003
# item: ('Thursday', 'westwood') , 0.003
# item: ('stapleton', 'Friday') , 0.003
# item: ('montbello', 'Tuesday') , 0.003
# item: ('Saturday', 'westwood') , 0.003
# item: ('college-view-south-platte', 'Tuesday') , 0.003
# item: ('Monday', 'sun-valley') , 0.003
# item: ('Saturday', 'cheesman-park') , 0.003
# item: ('mar-lee', 'Tuesday') , 0.003
# item: ('Thursday', 'speer') , 0.003
# item: ('23:59:00', 'montbello') , 0.003
# item: ('athmar-park', '12:00:00') , 0.003
# item: ('04:00:00', 'civic-center') , 0.003
# item: ('villa-park', '20:00:00') , 0.003
# item: ('16:00:00', 'elyria-swansea') , 0.003
# item: ('20:00:00', 'goldsmith') , 0.003
# item: ('sun-valley', 'Friday') , 0.003
# item: ('villa-park', '16:00:00') , 0.003
# item: ('Wednesday', '16:00:00', 'east-colfax') , 0.003
# item: ('20:00:00', 'east-colfax', 'Tuesday') , 0.003
# item: ('23:59:00', 'east-colfax', 'Wednesday') , 0.003
# item: ('five-points', '12:00:00', 'Tuesday') , 0.003
# item: ('23:59:00', 'five-points', 'Monday') , 0.003
# item: ('Wednesday', '16:00:00', 'civic-center') , 0.003
# item: ('Wednesday', '16:00:00', 'north-capitol-hill') , 0.003
# item: ('23:59:00', 'Saturday', 'east-colfax') , 0.003
# item: ('16:00:00', 'northeast-park-hill') , 0.003
# item: ('20:00:00', 'globeville') , 0.003
# item: ('Sunday', 'west-colfax') , 0.003
# item: ('west-colfax', 'Friday') , 0.003
# item: ('cole', 'Monday') , 0.003
# item: ('16:00:00', 'sun-valley') , 0.003
# item: ('westwood', '04:00:00') , 0.003
# item: ('college-view-south-platte', '20:00:00') , 0.003
# item: ('cole', '12:00:00') , 0.003
# item: ('Thursday', '16:00:00', 'north-capitol-hill') , 0.003
# item: ('Saturday', '23:59:00', 'cbd') , 0.003
# item: ('16:00:00', 'five-points', 'Monday') , 0.003
# item: ('Friday', '16:00:00', 'civic-center') , 0.003
# item: ('23:59:00', 'Thursday', 'east-colfax') , 0.003
# item: ('university-hills', '16:00:00') , 0.003
# item: ('23:59:00', 'cheesman-park') , 0.003
# item: ('sunnyside', '16:00:00') , 0.003
# item: ('stapleton', '20:00:00') , 0.003
# item: ('16:00:00', 'college-view-south-platte') , 0.003
# item: ('athmar-park', 'Monday') , 0.003
# item: ('Monday', 'mar-lee') , 0.003
# item: ('23:59:00', 'Friday', 'capitol-hill') , 0.003
# item: ('20:00:00', 'Wednesday', 'cbd') , 0.003
# item: ('Thursday', '20:00:00', 'city-park-west') , 0.003
# item: ('16:00:00', 'Wednesday', 'cbd') , 0.003
# item: ('Thursday', '16:00:00', 'east-colfax') , 0.003
# item: ('16:00:00', 'Monday', 'east-colfax') , 0.003
# item: ('auraria', '16:00:00') , 0.003
# item: ('Monday', 'north-capitol-hill') , 0.003
# item: ('Friday', 'union-station') , 0.003
# item: ('Monday', 'montbello') , 0.003
# item: ('globeville', 'Tuesday') , 0.003
# item: ('west-colfax', '12:00:00') , 0.003
# item: ('westwood', 'Friday') , 0.003
# item: ('23:59:00', 'cole') , 0.003
# item: ('23:59:00', 'baker') , 0.003
# item: ('20:00:00', 'speer') , 0.003
# item: ('baker', 'Wednesday') , 0.003
# item: ('baker', 'Thursday') , 0.003
# item: ('Saturday', '23:59:00', 'five-points') , 0.003
# item: ('Thursday', '20:00:00', 'civic-center') , 0.003
# item: ('Saturday', '20:00:00', 'capitol-hill') , 0.003
# item: ('Saturday', '20:00:00', 'east-colfax') , 0.003
# item: ('16:00:00', 'cbd', 'Tuesday') , 0.003
# item: ('Saturday', 'cole') , 0.003
# item: ('lincoln-park', 'Tuesday') , 0.003
# item: ('athmar-park', 'Friday') , 0.003
# item: ('athmar-park', 'Thursday') , 0.003
# item: ('Saturday', 'west-colfax') , 0.003
# item: ('stapleton', '04:00:00') , 0.003
# item: ('cbd', '20:00:00', 'Tuesday') , 0.003
# item: ('16:00:00', 'Friday', 'capitol-hill') , 0.003
# item: ('12:00:00', 'Friday', 'capitol-hill') , 0.003
# item: ('16:00:00', 'Monday', 'capitol-hill') , 0.003
# item: ('16:00:00', 'five-points', 'Friday') , 0.003
# item: ('16:00:00', 'east-colfax', 'Tuesday') , 0.003
# item: ('stapleton', 'Monday') , 0.004
# item: ('Saturday', 'lincoln-park') , 0.004
# item: ('stapleton', 'Thursday') , 0.004
# item: ('23:59:00', 'union-station') , 0.004
# item: ('08:00:00', 'Wednesday') , 0.004
# item: ('athmar-park', '20:00:00') , 0.004
# item: ('baker', 'Tuesday') , 0.004
# item: ('westwood', 'Tuesday') , 0.004
# item: ('23:59:00', 'athmar-park') , 0.004
# item: ('west-colfax', 'Wednesday') , 0.004
# item: ('23:59:00', 'westwood') , 0.004
# item: ('Sunday', 'north-capitol-hill') , 0.004
# item: ('23:59:00', 'villa-park') , 0.004
# item: ('ruby-hill', '16:00:00') , 0.004
# item: ('Sunday', 'lincoln-park') , 0.004
# item: ('Wednesday', '20:00:00', 'civic-center') , 0.004
# item: ('Thursday', '16:00:00', 'capitol-hill') , 0.004
# item: ('cheesman-park', '20:00:00', 'Tuesday') , 0.004
# item: ('Wednesday', '20:00:00', 'north-capitol-hill') , 0.004
# item: ('westwood', '20:00:00') , 0.004
# item: ('Saturday', 'north-capitol-hill') , 0.004
# item: ('cole', '16:00:00') , 0.004
# item: ('stapleton', 'Tuesday') , 0.004
# item: ('Thursday', 'montbello') , 0.004
# item: ('12:00:00', 'city-park-west') , 0.004
# item: ('cheesman-park', '12:00:00') , 0.004
# item: ('12:00:00', 'montbello') , 0.004
# item: ('08:00:00', 'Friday') , 0.004
# item: ('Sunday', '08:00:00') , 0.004
# item: ('08:00:00', 'Tuesday') , 0.004
# item: ('23:59:00', 'civic-center') , 0.004
# item: ('16:00:00', 'capitol-hill', 'Tuesday') , 0.004
# item: ('cheesman-park', 'Thursday', '20:00:00') , 0.004
# item: ('west-colfax', '04:00:00') , 0.004
# item: ('west-colfax', 'Thursday') , 0.004
# item: ('athmar-park', 'Tuesday') , 0.004
# item: ('athmar-park', 'Wednesday') , 0.004
# item: ('Monday', 'city-park-west') , 0.004
# item: ('Friday', 'city-park-west') , 0.004
# item: ('Wednesday', '20:00:00', 'east-colfax') , 0.004
# item: ('23:59:00', 'five-points', 'Wednesday') , 0.004
# item: ('Thursday', '16:00:00', 'cbd') , 0.004
# item: ('Thursday', '20:00:00', 'capitol-hill') , 0.004
# item: ('Wednesday', 'city-park-west') , 0.004
# item: ('20:00:00', 'union-station') , 0.004
# item: ('cole', '20:00:00') , 0.004
# item: ('04:00:00', 'lincoln-park') , 0.004
# item: ('20:00:00', 'montbello') , 0.004
# item: ('Wednesday', 'montbello') , 0.004
# item: ('04:00:00', 'cbd') , 0.004
# item: ('civic-center', 'Tuesday') , 0.004
# item: ('20:00:00', 'Monday', 'capitol-hill') , 0.004
# item: ('Sunday', 'capitol-hill') , 0.005
# item: ('stapleton', 'Wednesday') , 0.005
# item: ('Thursday', '08:00:00') , 0.005
# item: ('23:59:00', 'west-colfax') , 0.005
# item: ('16:00:00', 'globeville') , 0.005
# item: ('cheesman-park', 'Friday') , 0.005
# item: ('Monday', 'lincoln-park') , 0.005
# item: ('city-park-west', 'Tuesday') , 0.005
# item: ('west-colfax', '20:00:00') , 0.005
# item: ('Friday', 'lincoln-park') , 0.005
# item: ('16:00:00', 'city-park-west') , 0.005
# item: ('Sunday', 'civic-center') , 0.005
# item: ('Thursday', 'city-park-west') , 0.005
# item: ('Wednesday', 'lincoln-park') , 0.005
# item: ('baker', 'Friday') , 0.005
# item: ('23:59:00', 'lincoln-park') , 0.005
# item: ('Friday', 'north-capitol-hill') , 0.005
# item: ('west-colfax', 'Monday') , 0.005
# item: ('Sunday', 'five-points', '20:00:00') , 0.005
# item: ('23:59:00', 'Thursday', 'five-points') , 0.005
# item: ('20:00:00', 'Wednesday', 'capitol-hill') , 0.005
# item: ('Monday', 'civic-center') , 0.005
# item: ('Saturday', 'civic-center') , 0.005
# item: ('16:00:00', 'montbello') , 0.005
# item: ('12:00:00', 'north-capitol-hill') , 0.005
# item: ('cheesman-park', '20:00:00', 'Monday') , 0.005
# item: ('20:00:00', 'five-points', 'Monday') , 0.005
# item: ('16:00:00', 'five-points', 'Wednesday') , 0.005
# item: ('16:00:00', 'five-points', 'Tuesday') , 0.005
# item: ('cheesman-park', '20:00:00', 'Wednesday') , 0.005
# item: ('cheesman-park', '16:00:00') , 0.005
# item: ('16:00:00', 'mar-lee') , 0.005
# item: ('Sunday', 'cbd') , 0.005
# item: ('20:00:00', 'Friday', 'capitol-hill') , 0.005
# item: ('04:00:00', 'north-capitol-hill') , 0.006
# item: ('Saturday', '08:00:00') , 0.006
# item: ('16:00:00', 'Wednesday', 'capitol-hill') , 0.006
# item: ('Thursday', '16:00:00', 'five-points') , 0.006
# item: ('16:00:00', 'barnum-west') , 0.006
# item: ('cheesman-park', 'Tuesday') , 0.006
# item: ('Sunday', 'east-colfax') , 0.006
# item: ('baker', '16:00:00') , 0.006
# item: ('Monday', '08:00:00') , 0.006
# item: ('Thursday', 'lincoln-park') , 0.006
# item: ('Thursday', '20:00:00', 'cbd') , 0.006
# item: ('capitol-hill', '20:00:00', 'Tuesday') , 0.006
# item: ('16:00:00', 'westwood') , 0.006
# item: ('Sunday', '12:00:00') , 0.006
# item: ('stapleton', '12:00:00') , 0.006
# item: ('23:59:00', 'north-capitol-hill') , 0.006
# item: ('cheesman-park', 'Thursday') , 0.006
# item: ('12:00:00', 'lincoln-park') , 0.006
# item: ('north-capitol-hill', 'Tuesday') , 0.006
# item: ('west-colfax', '16:00:00') , 0.006
# item: ('Monday', 'cbd') , 0.006
# item: ('16:00:00', 'lincoln-park') , 0.006
# item: ('Friday', 'civic-center') , 0.007
# item: ('athmar-park', '16:00:00') , 0.007
# item: ('23:59:00', 'five-points', 'Friday') , 0.007
# item: ('Thursday', 'north-capitol-hill') , 0.007
# item: ('stapleton', '16:00:00') , 0.007
# item: ('04:00:00', 'capitol-hill') , 0.007
# item: ('baker', '20:00:00') , 0.007
# item: ('cheesman-park', 'Monday') , 0.007
# item: ('20:00:00', 'lincoln-park') , 0.007
# item: ('12:00:00', 'cbd') , 0.007
# item: ('five-points', '04:00:00') , 0.007
# item: ('Saturday', 'cbd') , 0.007
# item: ('Thursday', 'civic-center') , 0.007
# item: ('Friday', 'cbd') , 0.008
# item: ('five-points', '20:00:00', 'Friday') , 0.008
# item: ('Saturday', 'five-points', '20:00:00') , 0.008
# item: ('cheesman-park', 'Wednesday') , 0.008
# item: ('12:00:00', 'civic-center') , 0.008
# item: ('Saturday', 'capitol-hill') , 0.009
# item: ('five-points', '12:00:00') , 0.009
# item: ('Friday', 'east-colfax') , 0.009
# item: ('Saturday', '12:00:00') , 0.009
# item: ('Wednesday', 'civic-center') , 0.009
# item: ('Sunday', 'five-points') , 0.009
# item: ('Wednesday', 'cbd') , 0.009
# item: ('five-points', '20:00:00', 'Wednesday') , 0.009
# item: ('Wednesday', 'north-capitol-hill') , 0.010
# item: ('16:00:00', 'north-capitol-hill') , 0.010
# item: ('five-points', '20:00:00', 'Tuesday') , 0.010
# item: ('Saturday', 'east-colfax') , 0.010
# item: ('04:00:00', 'east-colfax') , 0.010
# item: ('five-points', 'Thursday', '20:00:00') , 0.011
# item: ('cbd', 'Tuesday') , 0.011
# item: ('Thursday', 'east-colfax') , 0.011
# item: ('23:59:00', 'cbd') , 0.011
# item: ('Monday', 'east-colfax') , 0.011
# item: ('12:00:00', 'east-colfax') , 0.011
# item: ('Saturday', '04:00:00') , 0.011
# item: ('Monday', 'capitol-hill') , 0.011
# item: ('20:00:00', 'north-capitol-hill') , 0.011
# item: ('east-colfax', 'Tuesday') , 0.012
# item: ('12:00:00', 'capitol-hill') , 0.012
# item: ('23:59:00', 'capitol-hill') , 0.012
# item: ('16:00:00', 'civic-center') , 0.012
# item: ('20:00:00', 'civic-center') , 0.012
# item: ('Thursday', 'capitol-hill') , 0.012
# item: ('five-points', 'Monday') , 0.013
# item: ('Wednesday', 'east-colfax') , 0.013
# item: ('20:00:00', 'city-park-west') , 0.013
# item: ('23:59:00', 'Sunday') , 0.014
# item: ('23:59:00', 'east-colfax') , 0.015
# item: ('capitol-hill', 'Tuesday') , 0.015
# item: ('20:00:00', 'east-colfax') , 0.015
# item: ('Sunday', '04:00:00') , 0.015
# item: ('Thursday', 'cbd') , 0.015
# item: ('Wednesday', 'capitol-hill') , 0.016
# item: ('Monday', '04:00:00') , 0.016
# item: ('Saturday', 'five-points') , 0.016
# item: ('Friday', 'capitol-hill') , 0.016
# item: ('Thursday', '04:00:00') , 0.016
# item: ('04:00:00', 'Friday') , 0.017
# item: ('16:00:00', 'east-colfax') , 0.017
# item: ('16:00:00', 'cbd') , 0.017
# item: ('04:00:00', 'Tuesday') , 0.017
# item: ('23:59:00', 'Monday') , 0.018
# item: ('Sunday', '16:00:00') , 0.018
# item: ('Saturday', '16:00:00') , 0.019
# item: ('04:00:00', 'Wednesday') , 0.019
# item: ('Monday', '12:00:00') , 0.019
# item: ('23:59:00', 'Tuesday') , 0.019
# item: ('20:00:00', 'cbd') , 0.020
# item: ('five-points', 'Tuesday') , 0.021
# item: ('cheesman-park', '20:00:00') , 0.021
# item: ('five-points', 'Wednesday') , 0.021
# item: ('five-points', 'Friday') , 0.021
# item: ('16:00:00', 'capitol-hill') , 0.023
# item: ('Sunday', '20:00:00') , 0.023
# item: ('Thursday', 'five-points') , 0.023
# item: ('Saturday', '23:59:00') , 0.024
# item: ('12:00:00', 'Wednesday') , 0.024
# item: ('Thursday', '12:00:00') , 0.025
# item: ('23:59:00', 'five-points') , 0.025
# item: ('12:00:00', 'Tuesday') , 0.025
# item: ('12:00:00', 'Friday') , 0.026
# item: ('16:00:00', 'five-points') , 0.026
# item: ('23:59:00', 'Thursday') , 0.027
# item: ('23:59:00', 'Wednesday') , 0.027
# item: ('20:00:00', 'capitol-hill') , 0.029
# item: ('Saturday', '20:00:00') , 0.033
# item: ('23:59:00', 'Friday') , 0.035
# item: ('16:00:00', 'Monday') , 0.036
# item: ('16:00:00', 'Friday') , 0.039
# item: ('20:00:00', 'Monday') , 0.039
# item: ('20:00:00', 'Friday') , 0.045
# item: ('20:00:00', 'Tuesday') , 0.046
# item: ('Thursday', '16:00:00') , 0.049
# item: ('16:00:00', 'Wednesday') , 0.051
# item: ('16:00:00', 'Tuesday') , 0.051
# item: ('Thursday', '20:00:00') , 0.053
# item: ('five-points', '20:00:00') , 0.055
# item: ('20:00:00', 'Wednesday') , 0.058
#
# ------------------------ RULES:
# Rule: ('cheesman-park', 'Tuesday') ==> ('20:00:00',) , 0.621
# Rule: ('Thursday', 'city-park-west') ==> ('20:00:00',) , 0.625
# Rule: ('cheesman-park', 'Wednesday') ==> ('20:00:00',) , 0.650
# Rule: ('cheesman-park', 'Thursday') ==> ('20:00:00',) , 0.667
# Rule: ('barnum-west', 'Tuesday') ==> ('16:00:00',) , 0.667
# Rule: ('cheesman-park', 'Monday') ==> ('20:00:00',) , 0.694
