# %%
import pandas as pd 
from datetime import datetime, date, time, timedelta

 
df = pd.read_csv("crime.csv") 
df.head()
# Out:
#    INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0   2016376978   2016376978521300          5213                       0
# 1  20186000994  20186000994239900          2399                       0
# 2  20166003953  20166003953230500          2305                       0
# 3    201872333    201872333239900          2399                       0
# 4   2017411405   2017411405230300          2303                       0
#
#                 OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0  weapon-unlawful-discharge-of          all-other-crimes
# 1                   theft-other                   larceny
# 2      theft-items-from-vehicle  theft-from-motor-vehicle
# 3                   theft-other                   larceny
# 4                theft-shoplift                   larceny
#
#     FIRST_OCCURRENCE_DATE   LAST_OCCURRENCE_DATE          REPORTED_DATE  \
# 0   6/15/2016 11:31:00 PM                    NaN  6/15/2016 11:31:00 PM
# 1  10/11/2017 12:30:00 PM  10/11/2017 4:55:00 PM   1/29/2018 5:53:00 PM
# 2     3/4/2016 8:00:00 PM   4/25/2016 8:00:00 AM   4/26/2016 9:02:00 PM
# 3    1/30/2018 7:20:00 PM                    NaN  1/30/2018 10:29:00 PM
# 4    6/22/2017 8:53:00 PM                    NaN   6/23/2017 4:09:00 PM
#
#       INCIDENT_ADDRESS      GEO_X      GEO_Y     GEO_LON    GEO_LAT  \
# 0                  NaN  3193983.0  1707251.0 -104.809881  39.773188
# 1                  NaN  3201943.0  1711852.0 -104.781434  39.785649
# 2  2932 S JOSEPHINE ST  3152762.0  1667011.0 -104.957381  39.663490
# 3  705 S COLORADO BLVD  3157162.0  1681320.0 -104.941440  39.702698
# 4       2810 E 1ST AVE  3153211.0  1686545.0 -104.955370  39.717107
#
#    DISTRICT_ID  PRECINCT_ID             NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# 0            5          521                   montbello         1           0
# 1            5          522  gateway-green-valley-ranch         1           0
# 2            3          314                   wellshire         1           0
# 3            3          312                     belcaro         1           0
# 4            3          311                cherry-creek         1           0

# %%
df['DATE'], df['TIME'] = df['FIRST_OCCURRENCE_DATE'].str.split(' ', 1).str


df['DATE'] = pd.to_datetime(df['DATE'])
df['day_of_week'] = df['DATE'].dt.day_name()
df
# Out:
#         INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0        2016376978   2016376978521300          5213                       0
# 1       20186000994  20186000994239900          2399                       0
# 2       20166003953  20166003953230500          2305                       0
# 3         201872333    201872333239900          2399                       0
# 4        2017411405   2017411405230300          2303                       0
# ...             ...                ...           ...                     ...
# 526095   2019688353   2019688353121200          1212                       0
# 526096   2019688368   2019688368540100          5401                       0
# 526097   2019688404   2019688404131302          1313                       2
# 526098   2019688441   2019688441131302          1313                       2
# 526099   2019688475   2019688475220300          2203                       0
#
#                      OFFENSE_TYPE_ID           OFFENSE_CATEGORY_ID  \
# 0       weapon-unlawful-discharge-of              all-other-crimes
# 1                        theft-other                       larceny
# 2           theft-items-from-vehicle      theft-from-motor-vehicle
# 3                        theft-other                       larceny
# 4                     theft-shoplift                       larceny
# ...                              ...                           ...
# 526095           robbery-car-jacking                       robbery
# 526096  traffic-accident-hit-and-run              traffic-accident
# 526097                    assault-dv  other-crimes-against-persons
# 526098                    assault-dv  other-crimes-against-persons
# 526099    burglary-business-by-force                      burglary
#
#          FIRST_OCCURRENCE_DATE   LAST_OCCURRENCE_DATE           REPORTED_DATE  \
# 0        6/15/2016 11:31:00 PM                    NaN   6/15/2016 11:31:00 PM
# 1       10/11/2017 12:30:00 PM  10/11/2017 4:55:00 PM    1/29/2018 5:53:00 PM
# 2          3/4/2016 8:00:00 PM   4/25/2016 8:00:00 AM    4/26/2016 9:02:00 PM
# 3         1/30/2018 7:20:00 PM                    NaN   1/30/2018 10:29:00 PM
# 4         6/22/2017 8:53:00 PM                    NaN    6/23/2017 4:09:00 PM
# ...                        ...                    ...                     ...
# 526095  10/27/2019 11:45:00 PM                    NaN  10/28/2019 12:08:00 AM
# 526096  10/28/2019 12:20:00 AM                    NaN  10/28/2019 12:35:00 AM
# 526097   10/28/2019 1:13:00 AM                    NaN   10/28/2019 3:26:00 AM
# 526098   10/28/2019 2:10:00 AM                    NaN   10/28/2019 4:25:00 AM
# 526099   10/28/2019 2:50:00 AM  10/28/2019 3:10:00 AM   10/28/2019 3:43:00 AM
#
#                  INCIDENT_ADDRESS  ...     GEO_LON    GEO_LAT  DISTRICT_ID  \
# 0                             NaN  ... -104.809881  39.773188            5
# 1                             NaN  ... -104.781434  39.785649            5
# 2             2932 S JOSEPHINE ST  ... -104.957381  39.663490            3
# 3             705 S COLORADO BLVD  ... -104.941440  39.702698            3
# 4                  2810 E 1ST AVE  ... -104.955370  39.717107            3
# ...                           ...  ...         ...        ...          ...
# 526095  E COLFAX AVE / N XENIA ST  ... -104.885821  39.740155            2
# 526096         1959 S BROADWAY ST  ... -104.987794  39.681001            3
# 526097            7030 N TOWER RD  ... -104.770112  39.824869            5
# 526098         3831 N SHOSHONE ST  ... -105.009777  39.769921            1
# 526099       4797 S WADSWORTH WAY  ... -105.087432  39.630572            4
#
#         PRECINCT_ID             NEIGHBORHOOD_ID  IS_CRIME IS_TRAFFIC  \
# 0               521                   montbello         1          0
# 1               522  gateway-green-valley-ranch         1          0
# 2               314                   wellshire         1          0
# 3               312                     belcaro         1          0
# 4               311                cherry-creek         1          0
# ...             ...                         ...       ...        ...
# 526095          223                 east-colfax         1          0
# 526096          313                    overland         0          1
# 526097          522                         dia         1          0
# 526098          111                   sunnyside         1          0
# 526099          423                     marston         1          0
#
#              DATE         TIME day_of_week
# 0      2016-06-15  11:31:00 PM   Wednesday
# 1      2017-10-11  12:30:00 PM   Wednesday
# 2      2016-03-04   8:00:00 PM      Friday
# 3      2018-01-30   7:20:00 PM     Tuesday
# 4      2017-06-22   8:53:00 PM    Thursday
# ...           ...          ...         ...
# 526095 2019-10-27  11:45:00 PM      Sunday
# 526096 2019-10-28  12:20:00 AM      Monday
# 526097 2019-10-28   1:13:00 AM      Monday
# 526098 2019-10-28   2:10:00 AM      Monday
# 526099 2019-10-28   2:50:00 AM      Monday
#
# [526100 rows x 22 columns]

# %%
df_DA = df[['OFFENSE_CATEGORY_ID', 'TIME', 'day_of_week','NEIGHBORHOOD_ID']]
df_DA = df_DA.loc[df_DA.OFFENSE_CATEGORY_ID == 'drug-alcohol']
df_DA_am =  df_DA.loc[df_DA.TIME.str[-2:] == "AM" ]
df_DA_am['TIME'] = [x[:-3] for x in df_DA_am['TIME']]
df_DA_am['TIME'] =  pd.to_datetime(df_DA_am['TIME'], format='%H:%M:%S')
# df_DA_am['TIME'] = [d.time() for d in df_DA_am['TIME']]
df_DA_am
# Out:
# /Users/missybueno/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/missybueno/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#        OFFENSE_CATEGORY_ID                TIME day_of_week  \
# 99            drug-alcohol 1900-01-01 12:51:00   Wednesday
# 208           drug-alcohol 1900-01-01 07:00:00   Wednesday
# 378           drug-alcohol 1900-01-01 11:00:00   Wednesday
# 433           drug-alcohol 1900-01-01 02:14:00   Wednesday
# 494           drug-alcohol 1900-01-01 02:14:00   Wednesday
# ...                    ...                 ...         ...
# 525573        drug-alcohol 1900-01-01 12:52:00      Friday
# 525736        drug-alcohol 1900-01-01 10:31:00      Sunday
# 525851        drug-alcohol 1900-01-01 11:00:00    Thursday
# 525893        drug-alcohol 1900-01-01 01:12:00     Tuesday
# 525958        drug-alcohol 1900-01-01 06:00:00   Wednesday
#
#                   NEIGHBORHOOD_ID
# 99                    east-colfax
# 208                     sunnyside
# 378                      highland
# 433                     sunnyside
# 494                     sunnyside
# ...                           ...
# 525573  college-view-south-platte
# 525736                  stapleton
# 525851                five-points
# 525893                 platt-park
# 525958                east-colfax
#
# [9074 rows x 4 columns]

# %%
df_DA = df_DA[['OFFENSE_CATEGORY_ID', 'TIME', 'day_of_week','NEIGHBORHOOD_ID']]
df_DA = df_DA.loc[df_DA.OFFENSE_CATEGORY_ID == 'drug-alcohol']
df_DA_pm =  df_DA.loc[df_DA.TIME.str[-2:] == "PM" ]
df_DA_pm['TIME'] = [x[:-3] for x in df_DA_pm['TIME']]
df_DA_pm['TIME'] =  pd.to_datetime(df_DA_pm['TIME'], format='%H:%M:%S')
df_DA_pm['TIME'] = df_DA_pm['TIME'] + timedelta(hours=12)
# df_DA_pm['TIME'] = [d.time() for d in df_DA_pm['TIME']]
df_DA_pm
# Out:
# /Users/missybueno/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/missybueno/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/missybueno/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        OFFENSE_CATEGORY_ID                TIME day_of_week  \
# 10            drug-alcohol 1900-01-01 20:04:00     Tuesday
# 34            drug-alcohol 1900-01-01 18:19:00     Tuesday
# 60            drug-alcohol 1900-01-01 17:00:00      Friday
# 76            drug-alcohol 1900-01-01 22:46:00     Tuesday
# 107           drug-alcohol 1900-01-01 19:44:00     Tuesday
# ...                    ...                 ...         ...
# 526048        drug-alcohol 1900-01-01 23:44:00      Friday
# 526071        drug-alcohol 1900-01-01 15:47:00      Sunday
# 526073        drug-alcohol 1900-01-01 16:25:00      Sunday
# 526074        drug-alcohol 1900-01-01 17:39:00      Sunday
# 526077        drug-alcohol 1900-01-01 17:56:00      Sunday
#
#             NEIGHBORHOOD_ID
# 10                goldsmith
# 34             lincoln-park
# 60             lincoln-park
# 76      northeast-park-hill
# 107      north-capitol-hill
# ...                     ...
# 526048         capitol-hill
# 526071       jefferson-park
# 526073            city-park
# 526074                baker
# 526077          five-points
#
# [25328 rows x 4 columns]

# %%
final_DA = pd.concat([df_DA_am, df_DA_pm], ignore_index=True, sort =False)

block1 = '09/19/18 04:00:00'
block2 = '09/19/18 08:00:00'
block3 = '09/19/18 12:00:00'
block4 = '09/19/18 16:00:00'
block5 = '09/19/18 20:00:00'
block6 = '09/19/18 23:59:00'
datetime_object1 = datetime.strptime(block1, '%m/%d/%y %H:%M:%S')
datetime_object2 = datetime.strptime(block2, '%m/%d/%y %H:%M:%S')
datetime_object3 = datetime.strptime(block3, '%m/%d/%y %H:%M:%S')
datetime_object4 = datetime.strptime(block4, '%m/%d/%y %H:%M:%S')
datetime_object5 = datetime.strptime(block5, '%m/%d/%y %H:%M:%S')
datetime_object6 = datetime.strptime(block6, '%m/%d/%y %H:%M:%S')

# %%
final_DA.loc[final_DA['TIME'].dt.time <= datetime_object1.time(), 'TIME'] = datetime_object1

final_DA.loc[(final_DA['TIME'].dt.time > datetime_object1.time())&(final_DA['TIME'].dt.time <= datetime_object2.time()), 'TIME'] = datetime_object2

final_DA.loc[(final_DA['TIME'].dt.time > datetime_object2.time())&(final_DA['TIME'].dt.time <= datetime_object3.time()), 'TIME'] = datetime_object3

final_DA.loc[(final_DA['TIME'].dt.time > datetime_object3.time())&(final_DA['TIME'].dt.time <= datetime_object4.time()), 'TIME'] = datetime_object4

final_DA.loc[(final_DA['TIME'].dt.time > datetime_object4.time())&(final_DA['TIME'].dt.time <= datetime_object5.time()), 'TIME'] = datetime_object5

final_DA.loc[(final_DA['TIME'].dt.time > datetime_object5.time())&(final_DA['TIME'].dt.time <= datetime_object6.time()), 'TIME'] = datetime_object6



final_DA['TIME'] = [d.time() for d in final_DA['TIME']]
final_DA
# Out:
#       OFFENSE_CATEGORY_ID      TIME day_of_week NEIGHBORHOOD_ID
# 0            drug-alcohol  16:00:00   Wednesday     east-colfax
# 1            drug-alcohol  08:00:00   Wednesday       sunnyside
# 2            drug-alcohol  12:00:00   Wednesday        highland
# 3            drug-alcohol  04:00:00   Wednesday       sunnyside
# 4            drug-alcohol  04:00:00   Wednesday       sunnyside
# ...                   ...       ...         ...             ...
# 34397        drug-alcohol  23:59:00      Friday    capitol-hill
# 34398        drug-alcohol  16:00:00      Sunday  jefferson-park
# 34399        drug-alcohol  20:00:00      Sunday       city-park
# 34400        drug-alcohol  20:00:00      Sunday           baker
# 34401        drug-alcohol  20:00:00      Sunday     five-points
#
# [34402 rows x 4 columns]

# %%
DA_csv = final_DA[['day_of_week','NEIGHBORHOOD_ID', 'TIME']]
DA_csv = DA_csv.sample(5000)
DA_csv.to_csv('DA.csv')


# !python apriori.py -f 'DA.csv' -s 0.0015
# Out:
# item: ('23:59:00', 'jefferson-park') , 0.002
# item: ('04:00:00', 'mar-lee') , 0.002
# item: ('chaffee-park', 'Monday') , 0.002
# item: ('college-view-south-platte', '04:00:00') , 0.002
# item: ('12:00:00', 'sunnyside') , 0.002
# item: ('city-park', '16:00:00') , 0.002
# item: ('city-park-west', '23:59:00') , 0.002
# item: ('12:00:00', 'elyria-swansea') , 0.002
# item: ('16:00:00', 'platt-park') , 0.002
# item: ('Friday', 'washington-park') , 0.002
# item: ('chaffee-park', '20:00:00') , 0.002
# item: ('berkeley', 'Tuesday') , 0.002
# item: ('speer', 'Wednesday') , 0.002
# item: ('ruby-hill', 'Thursday') , 0.002
# item: ('congress-park', '16:00:00') , 0.002
# item: ('Wednesday', 'sunnyside') , 0.002
# item: ('Wednesday', 'hampden-south') , 0.002
# item: ('harvey-park-south', '16:00:00') , 0.002
# item: ('Friday', 'washington-virginia-vale') , 0.002
# item: ('Monday', 'sunnyside') , 0.002
# item: ('college-view-south-platte', '23:59:00') , 0.002
# item: ('speer', 'Thursday') , 0.002
# item: ('sun-valley', 'Monday') , 0.002
# item: ('washington-virginia-vale', 'Monday') , 0.002
# item: ('hampden-south', 'Thursday') , 0.002
# item: ('gateway-green-valley-ranch', 'Wednesday') , 0.002
# item: ('Friday', 'university-park') , 0.002
# item: ('Friday', 'university-hills') , 0.002
# item: ('barnum', 'Monday') , 0.002
# item: ('virginia-village', '23:59:00') , 0.002
# item: ('highland', 'Tuesday') , 0.002
# item: ('clayton', 'Monday') , 0.002
# item: ('highland', '23:59:00') , 0.002
# item: ('harvey-park', 'Tuesday') , 0.002
# item: ('sunnyside', '20:00:00') , 0.002
# item: ('cole', '12:00:00') , 0.002
# item: ('04:00:00', 'south-park-hill') , 0.002
# item: ('auraria', '20:00:00') , 0.002
# item: ('speer', '12:00:00') , 0.002
# item: ('Friday', 'east-colfax', '16:00:00') , 0.002
# item: ('Monday', 'north-capitol-hill', '20:00:00') , 0.002
# item: ('cbd', 'Sunday', '20:00:00') , 0.002
# item: ('civic-center', 'Monday', '12:00:00') , 0.002
# item: ('east-colfax', '23:59:00', 'Thursday') , 0.002
# item: ('civic-center', 'Sunday', '20:00:00') , 0.002
# item: ('baker', '16:00:00', 'Tuesday') , 0.002
# item: ('Saturday', 'villa-park', '23:59:00') , 0.002
# item: ('lincoln-park', '16:00:00', 'Thursday') , 0.002
# item: ('16:00:00', 'Monday', 'cheesman-park') , 0.002
# item: ('capitol-hill', '23:59:00', 'Monday') , 0.002
# item: ('cbd', 'Tuesday', '20:00:00') , 0.002
# item: ('stapleton', '12:00:00', 'Thursday') , 0.002
# item: ('east-colfax', '04:00:00', 'Monday') , 0.002
# item: ('baker', 'Friday', '20:00:00') , 0.002
# item: ('23:59:00', 'five-points', 'Sunday') , 0.002
# item: ('Friday', 'west-colfax', '20:00:00') , 0.002
# item: ('west-colfax', '16:00:00', 'Monday') , 0.002
# item: ('cbd', '12:00:00', 'Tuesday') , 0.002
# item: ('16:00:00', 'Tuesday', 'westwood') , 0.002
# item: ('five-points', 'Wednesday', '04:00:00') , 0.002
# item: ('Friday', 'civic-center', '16:00:00') , 0.002
# item: ('highland', 'Monday') , 0.002
# item: ('Friday', 'ruby-hill') , 0.002
# item: ('cole', 'Tuesday') , 0.002
# item: ('16:00:00', 'berkeley') , 0.002
# item: ('23:59:00', 'goldsmith') , 0.002
# item: ('gateway-green-valley-ranch', '12:00:00') , 0.002
# item: ('Friday', 'overland') , 0.002
# item: ('regis', '16:00:00') , 0.002
# item: ('Tuesday', 'overland') , 0.002
# item: ('sun-valley', '23:59:00') , 0.002
# item: ('west-colfax', 'Tuesday') , 0.002
# item: ('16:00:00', 'washington-park') , 0.002
# item: ('Wednesday', 'washington-virginia-vale') , 0.002
# item: ('12:00:00', 'jefferson-park') , 0.002
# item: ('baker', 'Monday') , 0.002
# item: ('Friday', 'harvey-park') , 0.002
# item: ('clayton', 'Wednesday') , 0.002
# item: ('university-park', '20:00:00') , 0.002
# item: ('16:00:00', 'elyria-swansea') , 0.002
# item: ('Monday', 'montbello') , 0.002
# item: ('Thursday', 'auraria') , 0.002
# item: ('Wednesday', 'ruby-hill') , 0.002
# item: ('gateway-green-valley-ranch', '23:59:00') , 0.002
# item: ('cole', 'Thursday') , 0.002
# item: ('gateway-green-valley-ranch', 'Tuesday') , 0.002
# item: ('Wednesday', 'barnum-west') , 0.002
# item: ('college-view-south-platte', '20:00:00') , 0.002
# item: ('23:59:00', 'sunnyside') , 0.002
# item: ('harvey-park', '23:59:00') , 0.002
# item: ('barnum', '04:00:00') , 0.002
# item: ('12:00:00', 'globeville') , 0.002
# item: ('16:00:00', 'goldsmith') , 0.002
# item: ('globeville', '20:00:00') , 0.002
# item: ('04:00:00', 'auraria') , 0.002
# item: ('college-view-south-platte', '16:00:00') , 0.002
# item: ('Wednesday', 'auraria') , 0.002
# item: ('berkeley', 'Monday') , 0.002
# item: ('12:00:00', 'auraria') , 0.002
# item: ('valverde', '16:00:00') , 0.002
# item: ('Sunday', 'cheesman-park', '20:00:00') , 0.002
# item: ('civic-center', '16:00:00', 'Tuesday') , 0.002
# item: ('Wednesday', 'north-capitol-hill', '20:00:00') , 0.002
# item: ('east-colfax', 'Saturday', '16:00:00') , 0.002
# item: ('east-colfax', '12:00:00', 'Thursday') , 0.002
# item: ('west-colfax', '04:00:00', 'Monday') , 0.002
# item: ('12:00:00', 'montbello', 'Thursday') , 0.002
# item: ('capitol-hill', '23:59:00', 'Thursday') , 0.002
# item: ('Friday', 'city-park-west', '20:00:00') , 0.002
# item: ('capitol-hill', '23:59:00', 'Sunday') , 0.002
# item: ('east-colfax', 'Tuesday', '20:00:00') , 0.002
# item: ('capitol-hill', '16:00:00', 'Monday') , 0.002
# item: ('16:00:00', 'five-points', 'Sunday') , 0.002
# item: ('12:00:00', 'lincoln-park', 'Monday') , 0.002
# item: ('16:00:00', 'northeast-park-hill') , 0.002
# item: ('city-park-west', '04:00:00') , 0.002
# item: ('athmar-park', 'Monday') , 0.002
# item: ('gateway-green-valley-ranch', 'Friday') , 0.002
# item: ('union-station', 'Sunday') , 0.002
# item: ('gateway-green-valley-ranch', 'Monday') , 0.002
# item: ('gateway-green-valley-ranch', '20:00:00') , 0.002
# item: ('Wednesday', 'elyria-swansea') , 0.002
# item: ('Tuesday', 'northeast-park-hill') , 0.002
# item: ('Thursday', 'jefferson-park') , 0.002
# item: ('clayton', '16:00:00') , 0.002
# item: ('barnum-west', '20:00:00') , 0.002
# item: ('gateway-green-valley-ranch', '16:00:00') , 0.002
# item: ('goldsmith', '20:00:00') , 0.002
# item: ('Friday', 'globeville') , 0.002
# item: ('Friday', 'northeast-park-hill') , 0.002
# item: ('west-colfax', 'Thursday') , 0.002
# item: ('sloan-lake', '20:00:00') , 0.002
# item: ('Wednesday', 'villa-park') , 0.002
# item: ('baker', '04:00:00') , 0.002
# item: ('23:59:00', 'auraria') , 0.002
# item: ('08:00:00', 'cbd') , 0.002
# item: ('Friday', 'barnum-west') , 0.002
# item: ('Friday', 'barnum') , 0.002
# item: ('west-colfax', 'Sunday') , 0.002
# item: ('16:00:00', 'auraria') , 0.002
# item: ('Thursday', 'westwood') , 0.002
# item: ('goldsmith', 'Thursday') , 0.002
# item: ('Saturday', 'ruby-hill') , 0.002
# item: ('23:59:00', 'mar-lee') , 0.002
# item: ('athmar-park', '23:59:00') , 0.002
# item: ('east-colfax', '23:59:00', 'Saturday') , 0.002
# item: ('cbd', '23:59:00', 'Thursday') , 0.002
# item: ('five-points', '04:00:00', 'Tuesday') , 0.002
# item: ('Friday', 'north-capitol-hill', '20:00:00') , 0.002
# item: ('five-points', '23:59:00', 'Tuesday') , 0.002
# item: ('cbd', '12:00:00', 'Thursday') , 0.002
# item: ('Friday', 'union-station', '20:00:00') , 0.002
# item: ('12:00:00', 'five-points', 'Tuesday') , 0.002
# item: ('civic-center', '16:00:00', 'Sunday') , 0.002
# item: ('Saturday', 'five-points', '04:00:00') , 0.002
# item: ('capitol-hill', '12:00:00', 'Monday') , 0.002
# item: ('overland', '20:00:00') , 0.002
# item: ('sunnyside', 'Tuesday') , 0.002
# item: ('Friday', 'villa-park') , 0.002
# item: ('mar-lee', '20:00:00') , 0.002
# item: ('highland', '16:00:00') , 0.002
# item: ('23:59:00', 'ruby-hill') , 0.002
# item: ('Sunday', 'westwood') , 0.002
# item: ('college-view-south-platte', 'Tuesday') , 0.002
# item: ('Tuesday', 'globeville') , 0.002
# item: ('Monday', 'northeast-park-hill') , 0.002
# item: ('23:59:00', 'northeast-park-hill') , 0.002
# item: ('city-park', '12:00:00') , 0.002
# item: ('villa-park', 'Saturday') , 0.002
# item: ('Friday', 'valverde') , 0.002
# item: ('valverde', '20:00:00') , 0.002
# item: ('harvey-park', '04:00:00') , 0.002
# item: ('mar-lee', 'Sunday') , 0.002
# item: ('athmar-park', 'Friday') , 0.002
# item: ('hampden-south', 'Tuesday') , 0.002
# item: ('lincoln-park', 'Sunday') , 0.002
# item: ('barnum', 'Tuesday') , 0.002
# item: ('washington-virginia-vale', '16:00:00') , 0.002
# item: ('hampden-south', '20:00:00') , 0.002
# item: ('08:00:00', 'lincoln-park') , 0.002
# item: ('12:00:00', 'villa-park') , 0.002
# item: ('Friday', 'auraria') , 0.002
# item: ('Friday', 'speer') , 0.002
# item: ('08:00:00', 'five-points') , 0.002
# item: ('04:00:00', 'globeville') , 0.002
# item: ('west-colfax', 'Saturday') , 0.002
# item: ('chaffee-park', '16:00:00') , 0.002
# item: ('villa-park', '20:00:00') , 0.002
# item: ('virginia-village', 'Thursday') , 0.002
# item: ('cbd', '16:00:00', 'Tuesday') , 0.002
# item: ('east-colfax', 'Saturday', '20:00:00') , 0.002
# item: ('cbd', 'Saturday', '23:59:00') , 0.002
# item: ('north-capitol-hill', 'Tuesday', '20:00:00') , 0.002
# item: ('16:00:00', 'north-capitol-hill', 'Thursday') , 0.002
# item: ('Wednesday', '16:00:00', 'north-capitol-hill') , 0.002
# item: ('north-capitol-hill', '16:00:00', 'Monday') , 0.002
# item: ('cbd', 'Wednesday', '23:59:00') , 0.002
# item: ('capitol-hill', 'Friday', '16:00:00') , 0.002
# item: ('Wednesday', 'overland') , 0.002
# item: ('mar-lee', 'Tuesday') , 0.002
# item: ('Friday', 'sunnyside') , 0.002
# item: ('Friday', 'lincoln-park') , 0.002
# item: ('virginia-village', 'Wednesday') , 0.002
# item: ('23:59:00', 'globeville') , 0.002
# item: ('08:00:00', 'east-colfax') , 0.002
# item: ('elyria-swansea', 'Thursday') , 0.002
# item: ('Monday', 'globeville') , 0.002
# item: ('sun-valley', '20:00:00') , 0.002
# item: ('city-park-west', 'Wednesday') , 0.002
# item: ('barnum', '20:00:00') , 0.002
# item: ('barnum', '23:59:00') , 0.002
# item: ('harvey-park', '16:00:00') , 0.002
# item: ('mar-lee', 'Monday') , 0.002
# item: ('cole', '16:00:00') , 0.002
# item: ('barnum', 'Thursday') , 0.002
# item: ('speer', '16:00:00') , 0.002
# item: ('university-hills', '16:00:00') , 0.002
# item: ('16:00:00', 'overland') , 0.002
# item: ('athmar-park', 'Tuesday') , 0.002
# item: ('cbd', 'Wednesday', '04:00:00') , 0.002
# item: ('cbd', '16:00:00', 'Thursday') , 0.002
# item: ('civic-center', '16:00:00', 'Wednesday') , 0.002
# item: ('cbd', '16:00:00', 'Monday') , 0.002
# item: ('Friday', 'east-colfax', '04:00:00') , 0.002
# item: ('east-colfax', '16:00:00', 'Monday') , 0.002
# item: ('Saturday', 'cheesman-park') , 0.003
# item: ('12:00:00', 'westwood') , 0.003
# item: ('Saturday', 'westwood') , 0.003
# item: ('villa-park', 'Tuesday') , 0.003
# item: ('speer', '20:00:00') , 0.003
# item: ('ruby-hill', '16:00:00') , 0.003
# item: ('sun-valley', '16:00:00') , 0.003
# item: ('union-station', 'Tuesday') , 0.003
# item: ('villa-park', 'Monday') , 0.003
# item: ('union-station', 'Saturday') , 0.003
# item: ('ruby-hill', '20:00:00') , 0.003
# item: ('washington-virginia-vale', '20:00:00') , 0.003
# item: ('Wednesday', 'mar-lee') , 0.003
# item: ('12:00:00', 'five-points', 'Wednesday') , 0.003
# item: ('cbd', '12:00:00', 'Wednesday') , 0.003
# item: ('north-capitol-hill', 'Thursday', '20:00:00') , 0.003
# item: ('capitol-hill', 'Sunday', '20:00:00') , 0.003
# item: ('east-colfax', '16:00:00', 'Sunday') , 0.003
# item: ('Saturday', 'five-points', '16:00:00') , 0.003
# item: ('east-colfax', '12:00:00', 'Tuesday') , 0.003
# item: ('virginia-village', '16:00:00') , 0.003
# item: ('city-park-west', '12:00:00') , 0.003
# item: ('union-station', 'Thursday') , 0.003
# item: ('virginia-village', 'Tuesday') , 0.003
# item: ('12:00:00', 'cheesman-park') , 0.003
# item: ('12:00:00', 'washington-park') , 0.003
# item: ('23:59:00', 'overland') , 0.003
# item: ('athmar-park', '16:00:00') , 0.003
# item: ('union-station', '04:00:00') , 0.003
# item: ('08:00:00', 'civic-center') , 0.003
# item: ('23:59:00', 'washington-virginia-vale') , 0.003
# item: ('globeville', 'Thursday') , 0.003
# item: ('barnum', '16:00:00') , 0.003
# item: ('capitol-hill', 'Friday', '23:59:00') , 0.003
# item: ('city-park-west', 'Thursday', '20:00:00') , 0.003
# item: ('east-colfax', '16:00:00', 'Thursday') , 0.003
# item: ('20:00:00', 'civic-center', 'Wednesday') , 0.003
# item: ('five-points', '16:00:00', 'Monday') , 0.003
# item: ('city-park-west', 'Monday', '20:00:00') , 0.003
# item: ('ruby-hill', 'Monday') , 0.003
# item: ('Sunday', 'cheesman-park') , 0.003
# item: ('ruby-hill', '04:00:00') , 0.003
# item: ('Monday', 'westwood') , 0.003
# item: ('union-station', '12:00:00') , 0.003
# item: ('04:00:00', 'montbello') , 0.003
# item: ('union-station', 'Monday') , 0.003
# item: ('civic-center', '04:00:00') , 0.003
# item: ('baker', 'Tuesday') , 0.003
# item: ('16:00:00', 'hampden-south') , 0.003
# item: ('villa-park', '16:00:00') , 0.003
# item: ('east-colfax', '16:00:00', 'Tuesday') , 0.003
# item: ('cbd', 'Friday', '23:59:00') , 0.003
# item: ('cbd', 'Wednesday', '16:00:00') , 0.003
# item: ('baker', 'Thursday') , 0.003
# item: ('northeast-park-hill', '20:00:00') , 0.003
# item: ('stapleton', '23:59:00') , 0.003
# item: ('stapleton', 'Tuesday') , 0.003
# item: ('Friday', 'stapleton') , 0.003
# item: ('villa-park', 'Sunday') , 0.003
# item: ('Wednesday', 'five-points', '23:59:00') , 0.003
# item: ('cbd', 'Wednesday', '20:00:00') , 0.003
# item: ('athmar-park', '20:00:00') , 0.003
# item: ('elyria-swansea', '20:00:00') , 0.003
# item: ('civic-center', 'Saturday') , 0.003
# item: ('Friday', 'westwood') , 0.003
# item: ('baker', '23:59:00') , 0.003
# item: ('Wednesday', 'globeville') , 0.003
# item: ('16:00:00', 'sunnyside') , 0.003
# item: ('stapleton', 'Saturday') , 0.003
# item: ('Tuesday', 'westwood') , 0.003
# item: ('Wednesday', 'montbello') , 0.003
# item: ('Friday', 'montbello') , 0.003
# item: ('westwood', '20:00:00') , 0.003
# item: ('villa-park', '04:00:00') , 0.003
# item: ('Friday', 'west-colfax') , 0.003
# item: ('cole', '20:00:00') , 0.003
# item: ('capitol-hill', '12:00:00', 'Thursday') , 0.003
# item: ('cbd', 'Monday', '20:00:00') , 0.003
# item: ('capitol-hill', '12:00:00', 'Wednesday') , 0.003
# item: ('civic-center', 'Thursday', '20:00:00') , 0.003
# item: ('cbd', 'Friday', '20:00:00') , 0.003
# item: ('five-points', 'Sunday', '20:00:00') , 0.003
# item: ('16:00:00', 'Wednesday', 'lincoln-park') , 0.003
# item: ('five-points', 'Wednesday', '16:00:00') , 0.003
# item: ('04:00:00', 'north-capitol-hill') , 0.004
# item: ('08:00:00', 'Saturday') , 0.004
# item: ('baker', 'Wednesday') , 0.004
# item: ('union-station', '23:59:00') , 0.004
# item: ('Friday', 'cheesman-park') , 0.004
# item: ('Friday', 'sun-valley') , 0.004
# item: ('montbello', '20:00:00') , 0.004
# item: ('Tuesday', 'montbello') , 0.004
# item: ('20:00:00', 'cheesman-park', 'Thursday') , 0.004
# item: ('east-colfax', 'Wednesday', '16:00:00') , 0.004
# item: ('Saturday', 'five-points', '23:59:00') , 0.004
# item: ('Friday', 'east-colfax', '23:59:00') , 0.004
# item: ('east-colfax', '23:59:00', 'Tuesday') , 0.004
# item: ('city-park-west', 'Tuesday', '20:00:00') , 0.004
# item: ('stapleton', 'Thursday') , 0.004
# item: ('Saturday', 'lincoln-park') , 0.004
# item: ('cbd', 'Sunday') , 0.004
# item: ('stapleton', 'Monday') , 0.004
# item: ('Wednesday', 'westwood') , 0.004
# item: ('16:00:00', 'barnum-west') , 0.004
# item: ('union-station', 'Wednesday') , 0.004
# item: ('lincoln-park', '04:00:00') , 0.004
# item: ('Tuesday', 'cheesman-park', '20:00:00') , 0.004
# item: ('capitol-hill', 'Saturday', '20:00:00') , 0.004
# item: ('five-points', '23:59:00', 'Monday') , 0.004
# item: ('Friday', 'city-park-west') , 0.004
# item: ('city-park-west', '16:00:00') , 0.004
# item: ('virginia-village', '20:00:00') , 0.004
# item: ('stapleton', '04:00:00') , 0.004
# item: ('city-park-west', 'Monday') , 0.004
# item: ('cbd', 'Saturday', '20:00:00') , 0.004
# item: ('Friday', '16:00:00', 'five-points') , 0.004
# item: ('baker', 'Friday') , 0.004
# item: ('stapleton', '20:00:00') , 0.004
# item: ('08:00:00', 'Sunday') , 0.004
# item: ('04:00:00', 'westwood') , 0.004
# item: ('23:59:00', 'westwood') , 0.004
# item: ('capitol-hill', 'Thursday', '20:00:00') , 0.004
# item: ('stapleton', 'Wednesday') , 0.004
# item: ('23:59:00', 'north-capitol-hill') , 0.004
# item: ('capitol-hill', 'Friday', '20:00:00') , 0.004
# item: ('Friday', '23:59:00', 'five-points') , 0.004
# item: ('cbd', 'Thursday', '20:00:00') , 0.004
# item: ('capitol-hill', '16:00:00', 'Thursday') , 0.004
# item: ('villa-park', '23:59:00') , 0.005
# item: ('12:00:00', 'north-capitol-hill') , 0.005
# item: ('lincoln-park', 'Tuesday') , 0.005
# item: ('west-colfax', '23:59:00') , 0.005
# item: ('montbello', 'Thursday') , 0.005
# item: ('08:00:00', 'Wednesday') , 0.005
# item: ('west-colfax', '16:00:00') , 0.005
# item: ('west-colfax', 'Wednesday') , 0.005
# item: ('Friday', 'civic-center') , 0.005
# item: ('08:00:00', 'Tuesday') , 0.005
# item: ('Friday', 'north-capitol-hill') , 0.005
# item: ('civic-center', 'Tuesday') , 0.005
# item: ('08:00:00', 'Friday') , 0.005
# item: ('08:00:00', 'Thursday') , 0.005
# item: ('west-colfax', '04:00:00') , 0.005
# item: ('capitol-hill', 'Wednesday', '16:00:00') , 0.005
# item: ('five-points', 'Saturday', '20:00:00') , 0.005
# item: ('north-capitol-hill', 'Tuesday') , 0.005
# item: ('city-park-west', 'Thursday') , 0.005
# item: ('civic-center', '23:59:00') , 0.005
# item: ('Friday', 'union-station') , 0.005
# item: ('baker', '20:00:00') , 0.005
# item: ('stapleton', '12:00:00') , 0.005
# item: ('capitol-hill', 'Tuesday', '20:00:00') , 0.005
# item: ('five-points', '23:59:00', 'Thursday') , 0.005
# item: ('16:00:00', 'montbello') , 0.005
# item: ('lincoln-park', '23:59:00') , 0.005
# item: ('12:00:00', 'montbello') , 0.005
# item: ('Saturday', 'north-capitol-hill') , 0.005
# item: ('Monday', 'cheesman-park', '20:00:00') , 0.005
# item: ('five-points', '16:00:00', 'Tuesday') , 0.005
# item: ('east-colfax', 'Wednesday', '20:00:00') , 0.005
# item: ('23:59:00', 'cheesman-park') , 0.005
# item: ('civic-center', 'Monday') , 0.005
# item: ('union-station', '16:00:00') , 0.005
# item: ('12:00:00', 'Sunday') , 0.005
# item: ('lincoln-park', 'Thursday') , 0.005
# item: ('capitol-hill', 'Monday', '20:00:00') , 0.005
# item: ('16:00:00', 'globeville') , 0.006
# item: ('union-station', '20:00:00') , 0.006
# item: ('08:00:00', 'Monday') , 0.006
# item: ('west-colfax', 'Monday') , 0.006
# item: ('16:00:00', 'mar-lee') , 0.006
# item: ('five-points', '16:00:00', 'Thursday') , 0.006
# item: ('capitol-hill', '16:00:00', 'Tuesday') , 0.006
# item: ('16:00:00', 'cheesman-park') , 0.006
# item: ('cheesman-park', 'Thursday') , 0.006
# item: ('Monday', 'north-capitol-hill') , 0.006
# item: ('Tuesday', 'cheesman-park') , 0.006
# item: ('16:00:00', 'westwood') , 0.006
# item: ('civic-center', '12:00:00') , 0.006
# item: ('lincoln-park', '20:00:00') , 0.006
# item: ('12:00:00', 'lincoln-park') , 0.006
# item: ('stapleton', '16:00:00') , 0.006
# item: ('civic-center', 'Sunday') , 0.006
# item: ('Friday', 'five-points', '20:00:00') , 0.006
# item: ('baker', '16:00:00') , 0.006
# item: ('lincoln-park', 'Monday') , 0.006
# item: ('west-colfax', '20:00:00') , 0.006
# item: ('Wednesday', 'north-capitol-hill') , 0.006
# item: ('capitol-hill', '04:00:00') , 0.006
# item: ('cbd', '04:00:00') , 0.006
# item: ('capitol-hill', 'Sunday') , 0.007
# item: ('capitol-hill', 'Wednesday', '20:00:00') , 0.007
# item: ('Wednesday', 'lincoln-park') , 0.007
# item: ('city-park-west', 'Tuesday') , 0.007
# item: ('cbd', 'Tuesday') , 0.007
# item: ('civic-center', 'Thursday') , 0.007
# item: ('east-colfax', 'Monday') , 0.007
# item: ('north-capitol-hill', 'Thursday') , 0.007
# item: ('five-points', 'Sunday') , 0.008
# item: ('east-colfax', 'Sunday') , 0.008
# item: ('capitol-hill', 'Saturday') , 0.008
# item: ('Wednesday', 'cheesman-park', '20:00:00') , 0.008
# item: ('east-colfax', 'Saturday') , 0.008
# item: ('cbd', 'Saturday') , 0.008
# item: ('five-points', 'Monday', '20:00:00') , 0.008
# item: ('civic-center', 'Wednesday') , 0.008
# item: ('five-points', '04:00:00') , 0.008
# item: ('cbd', '12:00:00') , 0.008
# item: ('lincoln-park', '16:00:00') , 0.009
# item: ('east-colfax', '12:00:00') , 0.009
# item: ('east-colfax', 'Thursday') , 0.009
# item: ('Monday', 'cheesman-park') , 0.009
# item: ('five-points', 'Tuesday', '20:00:00') , 0.009
# item: ('12:00:00', 'five-points') , 0.009
# item: ('Wednesday', 'cheesman-park') , 0.009
# item: ('east-colfax', '04:00:00') , 0.009
# item: ('cbd', 'Friday') , 0.009
# item: ('Friday', 'east-colfax') , 0.009
# item: ('cbd', 'Monday') , 0.009
# item: ('five-points', 'Thursday', '20:00:00') , 0.009
# item: ('Wednesday', 'five-points', '20:00:00') , 0.010
# item: ('16:00:00', 'north-capitol-hill') , 0.010
# item: ('12:00:00', 'Saturday') , 0.011
# item: ('04:00:00', 'Sunday') , 0.011
# item: ('capitol-hill', '23:59:00') , 0.011
# item: ('civic-center', '20:00:00') , 0.011
# item: ('cbd', '23:59:00') , 0.011
# item: ('north-capitol-hill', '20:00:00') , 0.012
# item: ('civic-center', '16:00:00') , 0.012
# item: ('cbd', 'Thursday') , 0.012
# item: ('capitol-hill', 'Friday') , 0.012
# item: ('capitol-hill', 'Monday') , 0.012
# item: ('east-colfax', 'Tuesday') , 0.012
# item: ('capitol-hill', '12:00:00') , 0.013
# item: ('east-colfax', 'Wednesday') , 0.013
# item: ('city-park-west', '20:00:00') , 0.013
# item: ('capitol-hill', 'Tuesday') , 0.013
# item: ('cbd', '16:00:00') , 0.014
# item: ('east-colfax', '23:59:00') , 0.014
# item: ('east-colfax', '20:00:00') , 0.014
# item: ('cbd', 'Wednesday') , 0.014
# item: ('04:00:00', 'Thursday') , 0.014
# item: ('Saturday', '04:00:00') , 0.015
# item: ('Saturday', 'five-points') , 0.015
# item: ('capitol-hill', 'Thursday') , 0.015
# item: ('capitol-hill', 'Wednesday') , 0.017
# item: ('Friday', 'five-points') , 0.017
# item: ('Friday', '12:00:00') , 0.017
# item: ('23:59:00', 'Sunday') , 0.017
# item: ('five-points', 'Monday') , 0.017
# item: ('16:00:00', 'Sunday') , 0.017
# item: ('east-colfax', '16:00:00') , 0.018
# item: ('Saturday', '16:00:00') , 0.018
# item: ('Wednesday', '04:00:00') , 0.018
# item: ('04:00:00', 'Tuesday') , 0.019
# item: ('Friday', '04:00:00') , 0.019
# item: ('04:00:00', 'Monday') , 0.020
# item: ('capitol-hill', '16:00:00') , 0.021
# item: ('five-points', 'Tuesday') , 0.021
# item: ('Wednesday', 'five-points') , 0.021
# item: ('23:59:00', 'Tuesday') , 0.021
# item: ('12:00:00', 'Monday') , 0.021
# item: ('five-points', 'Thursday') , 0.021
# item: ('cbd', '20:00:00') , 0.022
# item: ('23:59:00', 'Monday') , 0.022
# item: ('Sunday', '20:00:00') , 0.023
# item: ('Wednesday', '23:59:00') , 0.023
# item: ('12:00:00', 'Thursday') , 0.023
# item: ('five-points', '23:59:00') , 0.024
# item: ('cheesman-park', '20:00:00') , 0.024
# item: ('12:00:00', 'Tuesday') , 0.025
# item: ('five-points', '16:00:00') , 0.025
# item: ('Saturday', '23:59:00') , 0.026
# item: ('23:59:00', 'Thursday') , 0.027
# item: ('12:00:00', 'Wednesday') , 0.028
# item: ('Saturday', '20:00:00') , 0.030
# item: ('capitol-hill', '20:00:00') , 0.032
# item: ('Friday', '23:59:00') , 0.036
# item: ('Friday', '16:00:00') , 0.036
# item: ('16:00:00', 'Monday') , 0.039
# item: ('16:00:00', 'Thursday') , 0.043
# item: ('Tuesday', '20:00:00') , 0.044
# item: ('Friday', '20:00:00') , 0.045
# item: ('Monday', '20:00:00') , 0.047
# item: ('16:00:00', 'Tuesday') , 0.049
# item: ('Thursday', '20:00:00') , 0.049
# item: ('Wednesday', '16:00:00') , 0.050
# item: ('five-points', '20:00:00') , 0.051
# item: ('Wednesday', '20:00:00') , 0.061
#
# ------------------------ RULES:
# Rule: ('Sunday', 'cheesman-park') ==> ('20:00:00',) , 0.600
# Rule: ('cheesman-park',) ==> ('20:00:00',) , 0.610
# Rule: ('cheesman-park', 'Thursday') ==> ('20:00:00',) , 0.621
# Rule: ('Tuesday', 'cheesman-park') ==> ('20:00:00',) , 0.655
# Rule: ('city-park-west', 'Monday') ==> ('20:00:00',) , 0.700
# Rule: ('villa-park', 'Saturday') ==> ('23:59:00',) , 0.727
# Rule: ('Wednesday', 'cheesman-park') ==> ('20:00:00',) , 0.848
