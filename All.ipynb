# %%
import pandas as pd 
from datetime import datetime, date, time, timedelta

df = pd.read_csv("crime.csv")

# %%
df['DATE'], df['TIME'] = df['FIRST_OCCURRENCE_DATE'].str.split(' ', 1).str


df['DATE'] = pd.to_datetime(df['DATE'])
df['day_of_week'] = df['DATE'].dt.day_name()

# %%
df = df[['OFFENSE_CATEGORY_ID', 'TIME', 'day_of_week','NEIGHBORHOOD_ID','GEO_LAT','GEO_LON']]
df_All_am =  df.loc[df.TIME.str[-2:] == "AM" ].copy()
df_All_am['TIME'] = [x[:-3] for x in df_All_am['TIME']]
df_All_am['TIME'] =  pd.to_datetime(df_All_am['TIME'], format='%H:%M:%S')


df_All_pm =  df.loc[df.TIME.str[-2:] == "PM" ].copy()
df_All_pm['TIME'] = [x[:-3] for x in df_All_pm['TIME']]
df_All_pm['TIME'] =  pd.to_datetime(df_All_pm['TIME'], format='%H:%M:%S')
df_All_pm['TIME'] = df_All_pm['TIME'] + timedelta(hours=12)

# %%
final = pd.concat([df_All_am, df_All_pm], ignore_index=True, sort =False)

block1 = '09/19/18 04:00:00'
block2 = '09/19/18 08:00:00'
block3 = '09/19/18 12:00:00'
block4 = '09/19/18 16:00:00'
block5 = '09/19/18 20:00:00'
block6 = '09/19/18 23:59:00'
datetime_object1 = datetime.strptime(block1, '%m/%d/%y %H:%M:%S')
datetime_object2 = datetime.strptime(block2, '%m/%d/%y %H:%M:%S')
datetime_object3 = datetime.strptime(block3, '%m/%d/%y %H:%M:%S')
datetime_object4 = datetime.strptime(block4, '%m/%d/%y %H:%M:%S')
datetime_object5 = datetime.strptime(block5, '%m/%d/%y %H:%M:%S')
datetime_object6 = datetime.strptime(block6, '%m/%d/%y %H:%M:%S')

# %%
final.loc[final['TIME'].dt.time <= datetime_object1.time(), 'TIME'] = datetime_object1

final.loc[(final['TIME'].dt.time > datetime_object1.time())&(final['TIME'].dt.time <= datetime_object2.time()), 'TIME'] = datetime_object2

final.loc[(final['TIME'].dt.time > datetime_object2.time())&(final['TIME'].dt.time <= datetime_object3.time()), 'TIME'] = datetime_object3

final.loc[(final['TIME'].dt.time > datetime_object3.time())&(final['TIME'].dt.time <= datetime_object4.time()), 'TIME'] = datetime_object4

final.loc[(final['TIME'].dt.time > datetime_object4.time())&(final['TIME'].dt.time <= datetime_object5.time()), 'TIME'] = datetime_object5

final.loc[(final['TIME'].dt.time > datetime_object5.time())&(final['TIME'].dt.time <= datetime_object6.time()), 'TIME'] = datetime_object6



final['TIME'] = [d.time() for d in final['TIME']]

# %%
final_csv = final[['day_of_week','NEIGHBORHOOD_ID', 'TIME']]
final_plot = final[['day_of_week','NEIGHBORHOOD_ID', 'TIME','GEO_LAT','GEO_LON']]
final_csv = final_csv.sample(20000)
final_csv.to_csv('All_Crimes.csv')

final_plot.to_csv('All_Crimes_Plot.csv')


# !python apriori.py -f 'All_Crimes.csv' -s 0.0017
# Out:
# item: ('auraria', 'Friday') , 0.002
# item: ('globeville', '23:59:00') , 0.002
# item: ('globeville', 'Monday') , 0.002
# item: ('sunnyside', '04:00:00') , 0.002
# item: ('sunnyside', 'Wednesday') , 0.002
# item: ('barnum', 'Saturday') , 0.002
# item: ('mar-lee', 'Tuesday') , 0.002
# item: ('16:00:00', 'lowry-field') , 0.002
# item: ('college-view-south-platte', '04:00:00') , 0.002
# item: ('Saturday', 'windsor') , 0.002
# item: ('villa-park', 'Monday') , 0.002
# item: ('virginia-village', '04:00:00') , 0.002
# item: ('Friday', 'berkeley') , 0.002
# item: ('mar-lee', '12:00:00') , 0.002
# item: ('virginia-village', 'Tuesday') , 0.002
# item: ('Sunday', 'cherry-creek') , 0.002
# item: ('hampden-south', 'Saturday') , 0.002
# item: ('Tuesday', 'congress-park') , 0.002
# item: ('20:00:00', 'Thursday', 'stapleton') , 0.002
# item: ('16:00:00', 'montclair') , 0.002
# item: ('elyria-swansea', '23:59:00') , 0.002
# item: ('sunnyside', 'Monday') , 0.002
# item: ('west-highland', '12:00:00') , 0.002
# item: ('athmar-park', 'Thursday') , 0.002
# item: ('23:59:00', 'congress-park') , 0.002
# item: ('sunnyside', 'Saturday') , 0.002
# item: ('city-park-west', '12:00:00') , 0.002
# item: ('washington-park-west', 'Thursday') , 0.002
# item: ('sunnyside', 'Friday') , 0.002
# item: ('jefferson-park', 'Saturday') , 0.002
# item: ('barnum', '04:00:00') , 0.002
# item: ('elyria-swansea', '04:00:00') , 0.002
# item: ('Sunday', 'elyria-swansea') , 0.002
# item: ('overland', '16:00:00') , 0.002
# item: ('Friday', '16:00:00', 'stapleton') , 0.002
# item: ('Wednesday', 'mar-lee') , 0.002
# item: ('athmar-park', 'Saturday') , 0.002
# item: ('overland', '23:59:00') , 0.002
# item: ('barnum', 'Tuesday') , 0.002
# item: ('Sunday', 'ruby-hill') , 0.002
# item: ('athmar-park', '12:00:00') , 0.002
# item: ('ruby-hill', 'Tuesday') , 0.002
# item: ('speer', 'Saturday') , 0.002
# item: ('Wednesday', 'cherry-creek') , 0.002
# item: ('Sunday', 'mar-lee') , 0.002
# item: ('Wednesday', '20:00:00', 'stapleton') , 0.002
# item: ('23:59:00', 'harvey-park') , 0.002
# item: ('washington-virginia-vale', 'Tuesday') , 0.002
# item: ('cheesman-park', 'Tuesday') , 0.002
# item: ('barnum', '16:00:00') , 0.002
# item: ('jefferson-park', '23:59:00') , 0.002
# item: ('northeast-park-hill', 'Saturday') , 0.002
# item: ('23:59:00', 'barnum-west') , 0.002
# item: ('city-park-west', 'Monday') , 0.002
# item: ('dia', '23:59:00') , 0.002
# item: ('Friday', 'virginia-village') , 0.002
# item: ('20:00:00', 'Tuesday', 'stapleton') , 0.002
# item: ('cheesman-park', 'Saturday') , 0.002
# item: ('elyria-swansea', 'Thursday') , 0.002
# item: ('washington-park-west', '20:00:00') , 0.002
# item: ('ruby-hill', '16:00:00') , 0.002
# item: ('20:00:00', 'university-park') , 0.002
# item: ('speer', 'Monday') , 0.002
# item: ('ruby-hill', 'Saturday') , 0.002
# item: ('20:00:00', 'goldsmith') , 0.002
# item: ('Wednesday', 'city-park-west') , 0.002
# item: ('Wednesday', 'college-view-south-platte') , 0.002
# item: ('university', '16:00:00') , 0.002
# item: ('Friday', 'athmar-park') , 0.002
# item: ('Sunday', 'sun-valley') , 0.002
# item: ('washington-virginia-vale', 'Monday') , 0.002
# item: ('college-view-south-platte', 'Monday') , 0.002
# item: ('college-view-south-platte', 'Thursday') , 0.002
# item: ('Wednesday', 'athmar-park') , 0.002
# item: ('Friday', 'congress-park') , 0.002
# item: ('20:00:00', 'sun-valley') , 0.002
# item: ('west-highland', '16:00:00') , 0.002
# item: ('athmar-park', 'Monday') , 0.002
# item: ('virginia-village', 'Thursday') , 0.002
# item: ('berkeley', '12:00:00') , 0.002
# item: ('23:59:00', 'city-park-west') , 0.002
# item: ('cheesman-park', 'Sunday') , 0.002
# item: ('04:00:00', 'villa-park') , 0.002
# item: ('Friday', 'city-park-west') , 0.002
# item: ('cherry-creek', '12:00:00') , 0.002
# item: ('cole', '20:00:00') , 0.002
# item: ('20:00:00', 'hale') , 0.002
# item: ('hale', '16:00:00') , 0.002
# item: ('hampden-south', '08:00:00') , 0.002
# item: ('dia', 'Thursday') , 0.002
# item: ('hampden-south', 'Monday') , 0.002
# item: ('clayton', '23:59:00') , 0.002
# item: ('Monday', 'congress-park') , 0.002
# item: ('highland', 'Saturday') , 0.002
# item: ('Sunday', 'hampden') , 0.002
# item: ('20:00:00', 'south-park-hill') , 0.002
# item: ('16:00:00', 'jefferson-park') , 0.002
# item: ('Thursday', 'villa-park') , 0.002
# item: ('Monday', 'harvey-park') , 0.002
# item: ('villa-park', '12:00:00') , 0.002
# item: ('Sunday', 'dia') , 0.002
# item: ('college-view-south-platte', '16:00:00') , 0.002
# item: ('globeville', 'Saturday') , 0.002
# item: ('gateway-green-valley-ranch', '08:00:00') , 0.002
# item: ('Sunday', 'college-view-south-platte') , 0.002
# item: ('hampden-south', '04:00:00') , 0.002
# item: ('five-points', '20:00:00', 'Thursday') , 0.002
# item: ('five-points', '20:00:00', 'Saturday') , 0.002
# item: ('Friday', 'cherry-creek') , 0.002
# item: ('cheesman-park', '23:59:00') , 0.002
# item: ('Friday', 'overland') , 0.002
# item: ('20:00:00', 'montclair') , 0.002
# item: ('Sunday', 'hampden-south') , 0.002
# item: ('auraria', '16:00:00') , 0.002
# item: ('12:00:00', 'congress-park') , 0.002
# item: ('16:00:00', 'sun-valley') , 0.002
# item: ('five-points', '23:59:00', 'Friday') , 0.002
# item: ('five-points', '20:00:00', 'Monday') , 0.002
# item: ('cheesman-park', 'Friday') , 0.002
# item: ('Friday', 'villa-park') , 0.002
# item: ('Friday', 'washington-virginia-vale') , 0.002
# item: ('Friday', 'elyria-swansea') , 0.002
# item: ('cheesman-park', '12:00:00') , 0.002
# item: ('union-station', 'Monday') , 0.002
# item: ('20:00:00', 'windsor') , 0.002
# item: ('20:00:00', 'ruby-hill') , 0.002
# item: ('cherry-creek', 'Saturday') , 0.002
# item: ('Wednesday', 'dia') , 0.002
# item: ('Friday', 'dia') , 0.002
# item: ('Sunday', '04:00:00', 'union-station') , 0.002
# item: ('athmar-park', '04:00:00') , 0.002
# item: ('sunnyside', '23:59:00') , 0.002
# item: ('speer', 'Thursday') , 0.002
# item: ('Sunday', 'north-capitol-hill') , 0.002
# item: ('cheesman-park', 'Thursday') , 0.002
# item: ('Sunday', 'globeville') , 0.002
# item: ('speer', 'Sunday') , 0.002
# item: ('five-points', '20:00:00', 'Friday') , 0.002
# item: ('dia', 'Saturday') , 0.002
# item: ('sunnyside', 'Sunday') , 0.002
# item: ('elyria-swansea', 'Monday') , 0.002
# item: ('elyria-swansea', 'Tuesday') , 0.002
# item: ('highland', 'Tuesday') , 0.002
# item: ('Sunday', 'villa-park') , 0.002
# item: ('Friday', 'college-view-south-platte') , 0.002
# item: ('Friday', 'mar-lee') , 0.002
# item: ('20:00:00', 'west-highland') , 0.002
# item: ('five-points', '20:00:00', 'Tuesday') , 0.002
# item: ('hampden', 'Saturday') , 0.002
# item: ('Wednesday', 'villa-park') , 0.002
# item: ('20:00:00', 'barnum') , 0.002
# item: ('Sunday', 'barnum') , 0.002
# item: ('gateway-green-valley-ranch', 'Saturday') , 0.002
# item: ('villa-park', 'Tuesday') , 0.002
# item: ('Friday', 'west-colfax') , 0.002
# item: ('Wednesday', 'hampden') , 0.002
# item: ('highland', 'Monday') , 0.002
# item: ('dia', '04:00:00') , 0.002
# item: ('20:00:00', 'jefferson-park') , 0.002
# item: ('sunnyside', '16:00:00') , 0.002
# item: ('dia', 'Tuesday') , 0.002
# item: ('cheesman-park', '04:00:00') , 0.002
# item: ('northeast-park-hill', '04:00:00') , 0.002
# item: ('Wednesday', 'washington-virginia-vale') , 0.002
# item: ('Friday', 'highland') , 0.002
# item: ('08:00:00', 'dia') , 0.002
# item: ('hampden-south', '23:59:00') , 0.002
# item: ('12:00:00', 'harvey-park') , 0.002
# item: ('highland', '04:00:00') , 0.002
# item: ('08:00:00', 'westwood') , 0.002
# item: ('west-colfax', 'Saturday') , 0.002
# item: ('hampden', 'Monday') , 0.002
# item: ('ruby-hill', '23:59:00') , 0.002
# item: ('five-points', 'Wednesday', '20:00:00') , 0.002
# item: ('north-capitol-hill', 'Saturday') , 0.002
# item: ('north-capitol-hill', 'Tuesday') , 0.002
# item: ('city-park-west', 'Tuesday') , 0.002
# item: ('speer', 'Wednesday') , 0.002
# item: ('cheesman-park', '16:00:00') , 0.002
# item: ('auraria', '20:00:00') , 0.002
# item: ('speer', 'Friday') , 0.002
# item: ('washington-virginia-vale', 'Thursday') , 0.002
# item: ('Friday', '20:00:00', 'stapleton') , 0.002
# item: ('speer', '12:00:00') , 0.003
# item: ('16:00:00', 'city-park-west') , 0.003
# item: ('hampden-south', 'Thursday') , 0.003
# item: ('20:00:00', 'university-hills') , 0.003
# item: ('berkeley', '16:00:00') , 0.003
# item: ('16:00:00', 'villa-park') , 0.003
# item: ('northeast-park-hill', 'Monday') , 0.003
# item: ('north-capitol-hill', 'Thursday') , 0.003
# item: ('washington-virginia-vale', '16:00:00') , 0.003
# item: ('Sunday', 'athmar-park') , 0.003
# item: ('washington-virginia-vale', '12:00:00') , 0.003
# item: ('Friday', 'hampden') , 0.003
# item: ('Wednesday', 'union-station') , 0.003
# item: ('cherry-creek', '16:00:00') , 0.003
# item: ('hampden-south', 'Tuesday') , 0.003
# item: ('Sunday', 'highland') , 0.003
# item: ('west-colfax', '12:00:00') , 0.003
# item: ('20:00:00', 'harvey-park') , 0.003
# item: ('Wednesday', 'hampden-south') , 0.003
# item: ('washington-virginia-vale', '23:59:00') , 0.003
# item: ('northeast-park-hill', '23:59:00') , 0.003
# item: ('globeville', 'Tuesday') , 0.003
# item: ('elyria-swansea', 'Saturday') , 0.003
# item: ('Friday', 'northeast-park-hill') , 0.003
# item: ('Wednesday', 'northeast-park-hill') , 0.003
# item: ('highland', '23:59:00') , 0.003
# item: ('barnum', '23:59:00') , 0.003
# item: ('westwood', 'Tuesday') , 0.003
# item: ('20:00:00', 'marston') , 0.003
# item: ('16:00:00', 'hampden') , 0.003
# item: ('northeast-park-hill', 'Thursday') , 0.003
# item: ('Friday', 'globeville') , 0.003
# item: ('globeville', '04:00:00') , 0.003
# item: ('Sunday', 'east-colfax') , 0.003
# item: ('20:00:00', 'athmar-park') , 0.003
# item: ('dia', 'Monday') , 0.003
# item: ('globeville', '12:00:00') , 0.003
# item: ('Friday', 'hampden-south') , 0.003
# item: ('speer', '04:00:00') , 0.003
# item: ('union-station', '12:00:00') , 0.003
# item: ('20:00:00', 'villa-park') , 0.003
# item: ('globeville', 'Thursday') , 0.003
# item: ('speer', '23:59:00') , 0.003
# item: ('college-view-south-platte', '23:59:00') , 0.003
# item: ('08:00:00', 'cbd') , 0.003
# item: ('Thursday', 'hampden') , 0.003
# item: ('lincoln-park', 'Saturday') , 0.003
# item: ('west-colfax', 'Thursday') , 0.003
# item: ('16:00:00', 'mar-lee') , 0.003
# item: ('04:00:00', 'civic-center') , 0.003
# item: ('westwood', 'Monday') , 0.003
# item: ('union-station', 'Tuesday') , 0.003
# item: ('16:00:00', 'athmar-park') , 0.003
# item: ('08:00:00', 'civic-center') , 0.003
# item: ('hampden-south', '12:00:00') , 0.003
# item: ('northeast-park-hill', '12:00:00') , 0.003
# item: ('Sunday', 'civic-center') , 0.003
# item: ('sunnyside', '20:00:00') , 0.003
# item: ('capitol-hill', '08:00:00') , 0.003
# item: ('cheesman-park', 'Monday') , 0.003
# item: ('Wednesday', 'gateway-green-valley-ranch') , 0.003
# item: ('Friday', 'north-capitol-hill') , 0.003
# item: ('04:00:00', 'west-colfax') , 0.003
# item: ('northeast-park-hill', 'Tuesday') , 0.003
# item: ('Sunday', 'west-colfax') , 0.003
# item: ('north-capitol-hill', '04:00:00') , 0.003
# item: ('elyria-swansea', '12:00:00') , 0.003
# item: ('Thursday', 'union-station') , 0.003
# item: ('Sunday', 'gateway-green-valley-ranch') , 0.003
# item: ('mar-lee', '23:59:00') , 0.003
# item: ('speer', '16:00:00') , 0.003
# item: ('gateway-green-valley-ranch', 'Tuesday') , 0.003
# item: ('dia', '12:00:00') , 0.003
# item: ('west-colfax', 'Tuesday') , 0.003
# item: ('Wednesday', 'west-colfax') , 0.003
# item: ('08:00:00', 'lincoln-park') , 0.003
# item: ('20:00:00', 'dia') , 0.003
# item: ('16:00:00', 'dia') , 0.003
# item: ('20:00:00', 'washington-virginia-vale') , 0.003
# item: ('highland', 'Thursday') , 0.003
# item: ('08:00:00', 'baker') , 0.003
# item: ('Wednesday', 'highland') , 0.003
# item: ('hampden-south', '16:00:00') , 0.003
# item: ('baker', '04:00:00') , 0.003
# item: ('five-points', '08:00:00') , 0.003
# item: ('speer', 'Tuesday') , 0.003
# item: ('athmar-park', '23:59:00') , 0.003
# item: ('north-capitol-hill', 'Monday') , 0.003
# item: ('gateway-green-valley-ranch', '04:00:00') , 0.003
# item: ('20:00:00', 'mar-lee') , 0.003
# item: ('Wednesday', 'westwood') , 0.003
# item: ('hampden', '12:00:00') , 0.003
# item: ('westwood', '12:00:00') , 0.003
# item: ('Friday', 'gateway-green-valley-ranch') , 0.003
# item: ('20:00:00', 'virginia-village') , 0.003
# item: ('gateway-green-valley-ranch', 'Thursday') , 0.003
# item: ('Saturday', 'civic-center') , 0.003
# item: ('Sunday', 'lincoln-park') , 0.003
# item: ('gateway-green-valley-ranch', '12:00:00') , 0.003
# item: ('elyria-swansea', '16:00:00') , 0.003
# item: ('north-capitol-hill', '23:59:00') , 0.003
# item: ('23:59:00', 'villa-park') , 0.003
# item: ('globeville', '16:00:00') , 0.003
# item: ('Thursday', 'westwood') , 0.003
# item: ('northeast-park-hill', '16:00:00') , 0.003
# item: ('20:00:00', 'hampden') , 0.003
# item: ('baker', 'Monday') , 0.003
# item: ('gateway-green-valley-ranch', 'Monday') , 0.003
# item: ('Sunday', 'baker') , 0.003
# item: ('20:00:00', 'city-park-west') , 0.003
# item: ('lincoln-park', '04:00:00') , 0.003
# item: ('20:00:00', 'college-view-south-platte') , 0.003
# item: ('highland', '12:00:00') , 0.003
# item: ('baker', '23:59:00') , 0.003
# item: ('east-colfax', '12:00:00') , 0.003
# item: ('east-colfax', 'Thursday') , 0.004
# item: ('20:00:00', 'congress-park') , 0.004
# item: ('east-colfax', 'Saturday') , 0.004
# item: ('east-colfax', '04:00:00') , 0.004
# item: ('gateway-green-valley-ranch', '16:00:00') , 0.004
# item: ('lincoln-park', '23:59:00') , 0.004
# item: ('23:59:00', 'hampden') , 0.004
# item: ('23:59:00', 'civic-center') , 0.004
# item: ('20:00:00', 'elyria-swansea') , 0.004
# item: ('north-capitol-hill', '16:00:00') , 0.004
# item: ('Wednesday', 'lincoln-park') , 0.004
# item: ('20:00:00', 'globeville') , 0.004
# item: ('west-colfax', 'Monday') , 0.004
# item: ('north-capitol-hill', '12:00:00') , 0.004
# item: ('highland', '16:00:00') , 0.004
# item: ('east-colfax', 'Tuesday') , 0.004
# item: ('westwood', 'Saturday') , 0.004
# item: ('Tuesday', 'civic-center') , 0.004
# item: ('baker', 'Tuesday') , 0.004
# item: ('Thursday', 'civic-center') , 0.004
# item: ('baker', 'Thursday') , 0.004
# item: ('Friday', 'civic-center') , 0.004
# item: ('Friday', 'east-colfax') , 0.004
# item: ('east-colfax', 'Monday') , 0.004
# item: ('Sunday', 'montbello') , 0.004
# item: ('08:00:00', 'montbello') , 0.004
# item: ('union-station', 'Saturday') , 0.004
# item: ('Wednesday', 'north-capitol-hill') , 0.004
# item: ('gateway-green-valley-ranch', '23:59:00') , 0.004
# item: ('Monday', 'civic-center') , 0.004
# item: ('20:00:00', 'hampden-south') , 0.004
# item: ('08:00:00', 'stapleton') , 0.004
# item: ('Friday', 'lincoln-park') , 0.004
# item: ('speer', '20:00:00') , 0.004
# item: ('montbello', '04:00:00') , 0.004
# item: ('cbd', '04:00:00') , 0.004
# item: ('04:00:00', 'westwood') , 0.004
# item: ('20:00:00', 'highland') , 0.004
# item: ('baker', 'Saturday') , 0.004
# item: ('20:00:00', 'cherry-creek') , 0.004
# item: ('Wednesday', 'civic-center') , 0.004
# item: ('lincoln-park', 'Thursday') , 0.004
# item: ('cbd', 'Saturday') , 0.004
# item: ('cheesman-park', '20:00:00') , 0.004
# item: ('lincoln-park', 'Monday') , 0.004
# item: ('16:00:00', 'west-colfax') , 0.004
# item: ('montbello', 'Saturday') , 0.004
# item: ('capitol-hill', 'Sunday') , 0.004
# item: ('Friday', 'union-station') , 0.004
# item: ('west-colfax', '23:59:00') , 0.004
# item: ('Friday', 'westwood') , 0.004
# item: ('Sunday', 'cbd') , 0.004
# item: ('20:00:00', 'west-colfax') , 0.004
# item: ('16:00:00', 'union-station') , 0.004
# item: ('23:59:00', 'union-station') , 0.004
# item: ('04:00:00', 'stapleton') , 0.004
# item: ('Sunday', 'stapleton') , 0.004
# item: ('20:00:00', 'northeast-park-hill') , 0.005
# item: ('20:00:00', 'civic-center') , 0.005
# item: ('Sunday', 'union-station') , 0.005
# item: ('capitol-hill', 'Tuesday') , 0.005
# item: ('Sunday', 'westwood') , 0.005
# item: ('16:00:00', 'westwood') , 0.005
# item: ('Wednesday', 'east-colfax') , 0.005
# item: ('cbd', 'Monday') , 0.005
# item: ('lincoln-park', '12:00:00') , 0.005
# item: ('20:00:00', 'westwood') , 0.005
# item: ('Wednesday', 'cbd') , 0.005
# item: ('20:00:00', 'north-capitol-hill') , 0.005
# item: ('lincoln-park', 'Tuesday') , 0.005
# item: ('Wednesday', 'baker') , 0.005
# item: ('20:00:00', 'union-station') , 0.005
# item: ('capitol-hill', 'Monday') , 0.005
# item: ('capitol-hill', 'Saturday') , 0.005
# item: ('capitol-hill', '04:00:00') , 0.005
# item: ('montbello', 'Monday') , 0.005
# item: ('capitol-hill', 'Thursday') , 0.005
# item: ('20:00:00', 'gateway-green-valley-ranch') , 0.005
# item: ('montbello', '23:59:00') , 0.005
# item: ('Friday', 'baker') , 0.005
# item: ('04:00:00', 'union-station') , 0.005
# item: ('Saturday', 'stapleton') , 0.005
# item: ('montbello', 'Tuesday') , 0.005
# item: ('montbello', '12:00:00') , 0.005
# item: ('baker', '12:00:00') , 0.005
# item: ('east-colfax', '23:59:00') , 0.005
# item: ('cbd', 'Tuesday') , 0.005
# item: ('20:00:00', 'east-colfax') , 0.005
# item: ('capitol-hill', 'Friday') , 0.005
# item: ('Wednesday', 'montbello') , 0.005
# item: ('capitol-hill', '12:00:00') , 0.005
# item: ('cbd', '23:59:00') , 0.005
# item: ('montbello', 'Thursday') , 0.006
# item: ('capitol-hill', 'Wednesday') , 0.006
# item: ('Friday', 'montbello') , 0.006
# item: ('civic-center', '12:00:00') , 0.006
# item: ('23:59:00', 'westwood') , 0.006
# item: ('20:00:00', 'lincoln-park') , 0.006
# item: ('cbd', 'Thursday') , 0.006
# item: ('16:00:00', 'civic-center') , 0.006
# item: ('Monday', 'stapleton') , 0.006
# item: ('Wednesday', 'stapleton') , 0.006
# item: ('16:00:00', 'lincoln-park') , 0.006
# item: ('five-points', '12:00:00') , 0.006
# item: ('five-points', 'Sunday') , 0.006
# item: ('east-colfax', '16:00:00') , 0.006
# item: ('Friday', 'cbd') , 0.006
# item: ('capitol-hill', '23:59:00') , 0.007
# item: ('Tuesday', 'stapleton') , 0.007
# item: ('five-points', 'Thursday') , 0.007
# item: ('16:00:00', 'baker') , 0.007
# item: ('23:59:00', 'stapleton') , 0.007
# item: ('20:00:00', 'baker') , 0.007
# item: ('Thursday', 'stapleton') , 0.007
# item: ('five-points', 'Monday') , 0.007
# item: ('cbd', '12:00:00') , 0.007
# item: ('five-points', '04:00:00') , 0.007
# item: ('five-points', 'Tuesday') , 0.007
# item: ('12:00:00', 'stapleton') , 0.007
# item: ('five-points', 'Wednesday') , 0.007
# item: ('Friday', 'stapleton') , 0.007
# item: ('capitol-hill', '16:00:00') , 0.007
# item: ('five-points', 'Saturday') , 0.008
# item: ('capitol-hill', '20:00:00') , 0.008
# item: ('16:00:00', 'montbello') , 0.008
# item: ('16:00:00', 'cbd') , 0.008
# item: ('five-points', 'Friday') , 0.008
# item: ('20:00:00', 'cbd') , 0.008
# item: ('08:00:00', 'Saturday') , 0.009
# item: ('20:00:00', 'montbello') , 0.009
# item: ('five-points', '16:00:00') , 0.009
# item: ('16:00:00', 'stapleton') , 0.009
# item: ('Sunday', '08:00:00') , 0.010
# item: ('five-points', '23:59:00') , 0.011
# item: ('20:00:00', 'stapleton') , 0.012
# item: ('Friday', '08:00:00') , 0.013
# item: ('five-points', '20:00:00') , 0.014
# item: ('08:00:00', 'Thursday') , 0.015
# item: ('08:00:00', 'Tuesday') , 0.015
# item: ('08:00:00', 'Monday') , 0.015
# item: ('Wednesday', '08:00:00') , 0.015
# item: ('04:00:00', 'Thursday') , 0.016
# item: ('04:00:00', 'Tuesday') , 0.016
# item: ('Wednesday', '04:00:00') , 0.017
# item: ('Sunday', '12:00:00') , 0.018
# item: ('Saturday', '12:00:00') , 0.018
# item: ('04:00:00', 'Monday') , 0.018
# item: ('Friday', '04:00:00') , 0.020
# item: ('23:59:00', 'Tuesday') , 0.021
# item: ('04:00:00', 'Saturday') , 0.021
# item: ('23:59:00', 'Monday') , 0.022
# item: ('23:59:00', 'Thursday') , 0.023
# item: ('Wednesday', '23:59:00') , 0.023
# item: ('Monday', '12:00:00') , 0.025
# item: ('Sunday', '16:00:00') , 0.025
# item: ('Sunday', '23:59:00') , 0.025
# item: ('Wednesday', '12:00:00') , 0.025
# item: ('Sunday', '04:00:00') , 0.026
# item: ('16:00:00', 'Saturday') , 0.026
# item: ('Thursday', '12:00:00') , 0.026
# item: ('Friday', '12:00:00') , 0.026
# item: ('Tuesday', '12:00:00') , 0.027
# item: ('20:00:00', 'Sunday') , 0.028
# item: ('16:00:00', 'Monday') , 0.028
# item: ('Friday', '23:59:00') , 0.029
# item: ('23:59:00', 'Saturday') , 0.029
# item: ('Wednesday', '16:00:00') , 0.029
# item: ('20:00:00', 'Saturday') , 0.030
# item: ('Friday', '16:00:00') , 0.030
# item: ('16:00:00', 'Thursday') , 0.031
# item: ('16:00:00', 'Tuesday') , 0.032
# item: ('20:00:00', 'Monday') , 0.033
# item: ('Wednesday', '20:00:00') , 0.035
# item: ('20:00:00', 'Thursday') , 0.035
# item: ('20:00:00', 'Tuesday') , 0.035
# item: ('Friday', '20:00:00') , 0.039
#
# ------------------------ RULES:
