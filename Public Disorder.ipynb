# %%
import pandas as pd 
from datetime import datetime, date, time, timedelta

 
df = pd.read_csv("crime.csv") 
df.head()
df['DATE'], df['TIME'] = df['FIRST_OCCURRENCE_DATE'].str.split(' ', 1).str


df['DATE'] = pd.to_datetime(df['DATE'])
df['day_of_week'] = df['DATE'].dt.day_name()

# %%
df_PD = df[['OFFENSE_CATEGORY_ID', 'TIME', 'day_of_week','NEIGHBORHOOD_ID','GEO_LAT','GEO_LON']]
df_PD = df_PD.loc[df_PD.OFFENSE_CATEGORY_ID == 'public-disorder'].copy()
df_PD_am =  df_PD.loc[df_PD.TIME.str[-2:] == "AM" ].copy()
df_PD_am['TIME'] = [x[:-3] for x in df_PD_am['TIME']]
df_PD_am['TIME'] =  pd.to_datetime(df_PD_am['TIME'], format='%H:%M:%S')

# %%
df_PD = df_PD[['OFFENSE_CATEGORY_ID', 'TIME', 'day_of_week','NEIGHBORHOOD_ID','GEO_LAT','GEO_LON']]
df_PD = df_PD.loc[df_PD.OFFENSE_CATEGORY_ID == 'public-disorder'].copy()
df_PD_pm =  df_PD.loc[df_PD.TIME.str[-2:] == "PM" ].copy()
df_PD_pm['TIME'] = [x[:-3] for x in df_PD_pm['TIME']]
df_PD_pm['TIME'] =  pd.to_datetime(df_PD_pm['TIME'], format='%H:%M:%S')
df_PD_pm['TIME'] = df_PD_pm['TIME'] + timedelta(hours=12)

# %%
final_PD = pd.concat([df_PD_am, df_PD_pm], ignore_index=True, sort =False)

block1 = '09/19/18 04:00:00'
block2 = '09/19/18 08:00:00'
block3 = '09/19/18 12:00:00'
block4 = '09/19/18 16:00:00'
block5 = '09/19/18 20:00:00'
block6 = '09/19/18 23:59:00'
datetime_object1 = datetime.strptime(block1, '%m/%d/%y %H:%M:%S')
datetime_object2 = datetime.strptime(block2, '%m/%d/%y %H:%M:%S')
datetime_object3 = datetime.strptime(block3, '%m/%d/%y %H:%M:%S')
datetime_object4 = datetime.strptime(block4, '%m/%d/%y %H:%M:%S')
datetime_object5 = datetime.strptime(block5, '%m/%d/%y %H:%M:%S')
datetime_object6 = datetime.strptime(block6, '%m/%d/%y %H:%M:%S')


final_PD.loc[final_PD['TIME'].dt.time <= datetime_object1.time(), 'TIME'] = datetime_object1

final_PD.loc[(final_PD['TIME'].dt.time > datetime_object1.time())&(final_PD['TIME'].dt.time <= datetime_object2.time()), 'TIME'] = datetime_object2

final_PD.loc[(final_PD['TIME'].dt.time > datetime_object2.time())&(final_PD['TIME'].dt.time <= datetime_object3.time()), 'TIME'] = datetime_object3

final_PD.loc[(final_PD['TIME'].dt.time > datetime_object3.time())&(final_PD['TIME'].dt.time <= datetime_object4.time()), 'TIME'] = datetime_object4

final_PD.loc[(final_PD['TIME'].dt.time > datetime_object4.time())&(final_PD['TIME'].dt.time <= datetime_object5.time()), 'TIME'] = datetime_object5

final_PD.loc[(final_PD['TIME'].dt.time > datetime_object5.time())&(final_PD['TIME'].dt.time <= datetime_object6.time()), 'TIME'] = datetime_object6



final_PD['TIME'] = [d.time() for d in final_PD['TIME']]
final_PD
# Out:
#       OFFENSE_CATEGORY_ID      TIME day_of_week NEIGHBORHOOD_ID    GEO_LAT  \
# 0         public-disorder  16:00:00     Tuesday       stapleton  39.775182
# 1         public-disorder  08:00:00      Sunday    cherry-creek  39.719075
# 2         public-disorder  04:00:00      Monday           baker  39.717051
# 3         public-disorder  04:00:00    Thursday      university  39.666272
# 4         public-disorder  04:00:00   Wednesday     five-points  39.758362
# ...                   ...       ...         ...             ...        ...
# 54580     public-disorder  20:00:00      Sunday     harvey-park  39.678880
# 54581     public-disorder  20:00:00      Sunday         windsor  39.697063
# 54582     public-disorder  23:59:00    Thursday    lincoln-park  39.737538
# 54583     public-disorder  20:00:00   Wednesday         clayton  39.769425
# 54584     public-disorder  20:00:00      Sunday        highland  39.755381
#
#           GEO_LON
# 0     -104.875976
# 1     -104.943407
# 2     -104.993087
# 3     -104.969146
# 4     -104.986866
# ...           ...
# 54580 -105.057570
# 54581 -104.895548
# 54582 -104.997949
# 54583 -104.946721
# 54584 -105.009555
#
# [54585 rows x 6 columns]

# %%
PD_csv = final_PD[['day_of_week','NEIGHBORHOOD_ID', 'TIME']]
PD_plot = final_PD[['day_of_week','NEIGHBORHOOD_ID', 'TIME','GEO_LAT','GEO_LON']]
PD_csv = PD_csv.sample(20000)
PD_csv.to_csv('PD.csv')
PD_plot.to_csv('PD_plot.csv')


# !python apriori.py -f 'PD.csv' -s 0.002
# Out:
# item: ('virginia-village', '04:00:00') , 0.002
# item: ('20:00:00', 'globeville') , 0.002
# item: ('04:00:00', 'university-park') , 0.002
# item: ('harvey-park-south', '12:00:00') , 0.002
# item: ('windsor', 'Sunday') , 0.002
# item: ('west-colfax', '08:00:00') , 0.002
# item: ('Wednesday', 'ruby-hill') , 0.002
# item: ('washington-virginia-vale', 'Wednesday') , 0.002
# item: ('clayton', '12:00:00') , 0.002
# item: ('Wednesday', 'speer') , 0.002
# item: ('overland', '20:00:00') , 0.002
# item: ('baker', '08:00:00') , 0.002
# item: ('villa-park', '04:00:00') , 0.002
# item: ('Sunday', 'sunnyside') , 0.002
# item: ('23:59:00', 'university-park') , 0.002
# item: ('23:59:00', 'bear-valley') , 0.002
# item: ('washington-virginia-vale', 'Sunday') , 0.002
# item: ('04:00:00', 'college-view-south-platte') , 0.002
# item: ('mar-lee', 'Monday') , 0.002
# item: ('villa-park', 'Friday') , 0.002
# item: ('berkeley', '23:59:00') , 0.002
# item: ('08:00:00', 'north-capitol-hill') , 0.002
# item: ('20:00:00', 'congress-park') , 0.002
# item: ('04:00:00', 'harvey-park') , 0.002
# item: ('hampden-south', 'Saturday') , 0.002
# item: ('04:00:00', 'city-park-west') , 0.002
# item: ('23:59:00', 'harvey-park-south') , 0.002
# item: ('harvey-park-south', '16:00:00') , 0.002
# item: ('04:00:00', 'university-hills') , 0.002
# item: ('23:59:00', 'marston') , 0.002
# item: ('hampden', 'Tuesday') , 0.002
# item: ('sun-valley', '23:59:00') , 0.002
# item: ('barnum', 'Monday') , 0.002
# item: ('Wednesday', 'mar-lee') , 0.002
# item: ('hampden-south', 'Monday') , 0.002
# item: ('sun-valley', '20:00:00') , 0.002
# item: ('04:00:00', 'berkeley') , 0.002
# item: ('Sunday', 'speer') , 0.002
# item: ('whittier', '16:00:00') , 0.002
# item: ('Sunday', 'harvey-park') , 0.002
# item: ('barnum', 'Saturday') , 0.002
# item: ('Thursday', 'mar-lee') , 0.002
# item: ('sunnyside', 'Friday') , 0.002
# item: ('23:59:00', 'university') , 0.002
# item: ('20:00:00', 'university-hills') , 0.002
# item: ('elyria-swansea', '04:00:00') , 0.002
# item: ('ruby-hill', 'Saturday') , 0.002
# item: ('speer', 'Friday') , 0.002
# item: ('Sunday', 'highland') , 0.002
# item: ('mar-lee', 'Friday') , 0.002
# item: ('east-colfax', '23:59:00', 'Tuesday') , 0.002
# item: ('elyria-swansea', 'Friday') , 0.002
# item: ('west-highland', '20:00:00') , 0.002
# item: ('sunnyside', '12:00:00') , 0.002
# item: ('Wednesday', 'baker') , 0.002
# item: ('16:00:00', 'bear-valley') , 0.002
# item: ('mar-lee', 'Saturday') , 0.002
# item: ('20:00:00', 'five-points', 'Friday') , 0.002
# item: ('04:00:00', 'Sunday', 'five-points') , 0.002
# item: ('16:00:00', 'cole') , 0.002
# item: ('Sunday', 'northeast-park-hill') , 0.002
# item: ('harvey-park', 'Friday') , 0.002
# item: ('sunnyside', 'Monday') , 0.002
# item: ('highland', 'Tuesday') , 0.002
# item: ('athmar-park', '16:00:00') , 0.002
# item: ('Thursday', 'baker') , 0.002
# item: ('east-colfax', 'Monday') , 0.002
# item: ('goldsmith', '23:59:00') , 0.002
# item: ('washington-virginia-vale', 'Thursday') , 0.002
# item: ('cheesman-park', 'Monday') , 0.002
# item: ('mar-lee', '04:00:00') , 0.002
# item: ('hampden-south', 'Sunday') , 0.002
# item: ('20:00:00', 'cole') , 0.002
# item: ('16:00:00', 'harvey-park') , 0.002
# item: ('cheesman-park', 'Tuesday') , 0.002
# item: ('20:00:00', 'college-view-south-platte') , 0.002
# item: ('Wednesday', 'elyria-swansea') , 0.002
# item: ('Thursday', 'city-park-west') , 0.002
# item: ('sloan-lake', 'Sunday') , 0.002
# item: ('12:00:00', 'bear-valley') , 0.002
# item: ('washington-virginia-vale', 'Tuesday') , 0.002
# item: ('04:00:00', 'northeast-park-hill') , 0.002
# item: ('baker', 'Friday') , 0.002
# item: ('16:00:00', 'speer') , 0.002
# item: ('04:00:00', 'sunnyside') , 0.002
# item: ('barnum', '20:00:00') , 0.002
# item: ('Monday', 'harvey-park') , 0.002
# item: ('city-park-west', '16:00:00') , 0.002
# item: ('04:00:00', 'stapleton') , 0.002
# item: ('Monday', 'north-capitol-hill') , 0.002
# item: ('east-colfax', 'Sunday') , 0.002
# item: ('sunnyside', 'Saturday') , 0.002
# item: ('city-park-west', 'Sunday') , 0.002
# item: ('union-station', 'Monday') , 0.002
# item: ('baker', 'Sunday') , 0.002
# item: ('Thursday', 'northeast-park-hill') , 0.002
# item: ('23:59:00', 'five-points', 'Saturday') , 0.002
# item: ('highland', 'Monday') , 0.002
# item: ('barnum', 'Sunday') , 0.002
# item: ('stapleton', 'Tuesday') , 0.002
# item: ('baker', '12:00:00') , 0.002
# item: ('washington-virginia-vale', 'Friday') , 0.002
# item: ('mar-lee', '16:00:00') , 0.002
# item: ('Thursday', 'elyria-swansea') , 0.002
# item: ('washington-virginia-vale', 'Monday') , 0.002
# item: ('16:00:00', 'northeast-park-hill') , 0.003
# item: ('north-capitol-hill', 'Tuesday') , 0.003
# item: ('sloan-lake', '16:00:00') , 0.003
# item: ('civic-center', 'Friday') , 0.003
# item: ('elyria-swansea', 'Saturday') , 0.003
# item: ('city-park-west', '23:59:00') , 0.003
# item: ('Thursday', 'union-station') , 0.003
# item: ('04:00:00', 'hampden-south') , 0.003
# item: ('hampden', 'Monday') , 0.003
# item: ('villa-park', '20:00:00') , 0.003
# item: ('washington-virginia-vale', 'Saturday') , 0.003
# item: ('clayton', '23:59:00') , 0.003
# item: ('Thursday', 'hampden') , 0.003
# item: ('northeast-park-hill', 'Friday') , 0.003
# item: ('sloan-lake', '23:59:00') , 0.003
# item: ('Wednesday', 'stapleton') , 0.003
# item: ('04:00:00', 'baker') , 0.003
# item: ('mar-lee', 'Sunday') , 0.003
# item: ('northeast-park-hill', '12:00:00') , 0.003
# item: ('20:00:00', 'speer') , 0.003
# item: ('Thursday', 'harvey-park') , 0.003
# item: ('stapleton', 'Sunday') , 0.003
# item: ('westwood', 'Monday') , 0.003
# item: ('Sunday', 'north-capitol-hill') , 0.003
# item: ('20:00:00', 'sunnyside') , 0.003
# item: ('east-colfax', '12:00:00') , 0.003
# item: ('23:59:00', 'college-view-south-platte') , 0.003
# item: ('baker', 'Monday') , 0.003
# item: ('ruby-hill', '20:00:00') , 0.003
# item: ('elyria-swansea', '23:59:00') , 0.003
# item: ('Wednesday', 'north-capitol-hill') , 0.003
# item: ('athmar-park', '20:00:00') , 0.003
# item: ('20:00:00', 'harvey-park') , 0.003
# item: ('capitol-hill', '08:00:00') , 0.003
# item: ('washington-virginia-vale', '23:59:00') , 0.003
# item: ('barnum', '04:00:00') , 0.003
# item: ('city-park-west', '12:00:00') , 0.003
# item: ('highland', 'Friday') , 0.003
# item: ('athmar-park', 'Saturday') , 0.003
# item: ('Saturday', 'north-capitol-hill') , 0.003
# item: ('stapleton', '12:00:00') , 0.003
# item: ('union-station', 'Tuesday') , 0.003
# item: ('20:00:00', 'lowry-field') , 0.003
# item: ('harvey-park', '12:00:00') , 0.003
# item: ('08:00:00', 'gateway-green-valley-ranch') , 0.003
# item: ('Wednesday', 'highland') , 0.003
# item: ('civic-center', 'Sunday') , 0.003
# item: ('civic-center', 'Saturday') , 0.003
# item: ('cheesman-park', 'Saturday') , 0.003
# item: ('Thursday', 'north-capitol-hill') , 0.003
# item: ('Wednesday', 'sunnyside') , 0.003
# item: ('washington-virginia-vale', '16:00:00') , 0.003
# item: ('hampden-south', '20:00:00') , 0.003
# item: ('lincoln-park', '08:00:00') , 0.003
# item: ('Wednesday', 'northeast-park-hill') , 0.003
# item: ('04:00:00', 'north-capitol-hill') , 0.003
# item: ('hampden-south', '23:59:00') , 0.003
# item: ('washington-virginia-vale', '04:00:00') , 0.003
# item: ('union-station', '12:00:00') , 0.003
# item: ('04:00:00', 'highland') , 0.003
# item: ('hampden', '12:00:00') , 0.003
# item: ('Friday', 'north-capitol-hill') , 0.003
# item: ('sunnyside', '16:00:00') , 0.003
# item: ('16:00:00', 'north-capitol-hill') , 0.003
# item: ('highland', 'Saturday') , 0.003
# item: ('Wednesday', 'union-station') , 0.003
# item: ('barnum', '23:59:00') , 0.003
# item: ('Thursday', 'highland') , 0.003
# item: ('Thursday', 'west-colfax') , 0.003
# item: ('washington-virginia-vale', '20:00:00') , 0.003
# item: ('baker', 'Tuesday') , 0.003
# item: ('cheesman-park', '16:00:00') , 0.003
# item: ('Wednesday', 'city-park-west') , 0.003
# item: ('villa-park', '23:59:00') , 0.003
# item: ('ruby-hill', '23:59:00') , 0.003
# item: ('04:00:00', 'civic-center') , 0.003
# item: ('baker', 'Saturday') , 0.003
# item: ('cheesman-park', '23:59:00') , 0.003
# item: ('westwood', 'Tuesday') , 0.003
# item: ('Thursday', 'stapleton') , 0.003
# item: ('hampden', 'Saturday') , 0.003
# item: ('athmar-park', '04:00:00') , 0.003
# item: ('cbd', '08:00:00') , 0.003
# item: ('ruby-hill', 'Sunday') , 0.003
# item: ('04:00:00', 'hampden') , 0.003
# item: ('Saturday', 'northeast-park-hill') , 0.003
# item: ('athmar-park', 'Sunday') , 0.003
# item: ('23:59:00', 'sunnyside') , 0.003
# item: ('stapleton', 'Saturday') , 0.003
# item: ('20:00:00', 'highland') , 0.003
# item: ('Thursday', 'civic-center') , 0.003
# item: ('Wednesday', 'hampden') , 0.003
# item: ('westwood', 'Friday') , 0.003
# item: ('baker', '23:59:00') , 0.003
# item: ('08:00:00', 'montbello') , 0.003
# item: ('hampden', 'Friday') , 0.003
# item: ('04:00:00', 'ruby-hill') , 0.003
# item: ('highland', '16:00:00') , 0.003
# item: ('lincoln-park', 'Tuesday') , 0.003
# item: ('lincoln-park', 'Sunday') , 0.003
# item: ('washington-virginia-vale', '12:00:00') , 0.003
# item: ('elyria-swansea', '16:00:00') , 0.003
# item: ('12:00:00', 'north-capitol-hill') , 0.003
# item: ('lincoln-park', 'Saturday') , 0.003
# item: ('Sunday', 'hampden') , 0.003
# item: ('23:59:00', 'north-capitol-hill') , 0.003
# item: ('civic-center', 'Monday') , 0.003
# item: ('elyria-swansea', '20:00:00') , 0.003
# item: ('mar-lee', '23:59:00') , 0.003
# item: ('23:59:00', 'speer') , 0.003
# item: ('Thursday', 'east-colfax') , 0.004
# item: ('cheesman-park', '20:00:00') , 0.004
# item: ('23:59:00', 'harvey-park') , 0.004
# item: ('Wednesday', 'civic-center') , 0.004
# item: ('Thursday', 'westwood') , 0.004
# item: ('highland', '12:00:00') , 0.004
# item: ('west-colfax', 'Sunday') , 0.004
# item: ('west-colfax', 'Friday') , 0.004
# item: ('mar-lee', '20:00:00') , 0.004
# item: ('athmar-park', '23:59:00') , 0.004
# item: ('west-colfax', 'Saturday') , 0.004
# item: ('lincoln-park', 'Monday') , 0.004
# item: ('Wednesday', 'westwood') , 0.004
# item: ('20:00:00', 'northeast-park-hill') , 0.004
# item: ('23:59:00', 'highland') , 0.004
# item: ('civic-center', 'Tuesday') , 0.004
# item: ('Monday', 'gateway-green-valley-ranch') , 0.004
# item: ('west-colfax', '12:00:00') , 0.004
# item: ('23:59:00', 'northeast-park-hill') , 0.004
# item: ('capitol-hill', 'Tuesday') , 0.004
# item: ('20:00:00', 'hampden') , 0.004
# item: ('baker', '20:00:00') , 0.004
# item: ('04:00:00', 'east-colfax') , 0.004
# item: ('west-colfax', 'Tuesday') , 0.004
# item: ('west-colfax', 'Monday') , 0.004
# item: ('baker', '16:00:00') , 0.004
# item: ('20:00:00', 'city-park-west') , 0.004
# item: ('westwood', '12:00:00') , 0.004
# item: ('20:00:00', 'civic-center') , 0.004
# item: ('hampden', '16:00:00') , 0.004
# item: ('east-colfax', 'Saturday') , 0.004
# item: ('civic-center', '23:59:00') , 0.004
# item: ('union-station', '16:00:00') , 0.004
# item: ('Wednesday', 'cbd') , 0.004
# item: ('union-station', 'Friday') , 0.004
# item: ('civic-center', '16:00:00') , 0.004
# item: ('Thursday', 'lincoln-park') , 0.004
# item: ('stapleton', '16:00:00') , 0.004
# item: ('04:00:00', 'lincoln-park') , 0.004
# item: ('20:00:00', 'north-capitol-hill') , 0.004
# item: ('04:00:00', 'westwood') , 0.004
# item: ('westwood', '20:00:00') , 0.004
# item: ('Thursday', 'gateway-green-valley-ranch') , 0.004
# item: ('Sunday', 'cbd') , 0.004
# item: ('stapleton', 'Friday') , 0.004
# item: ('westwood', 'Saturday') , 0.004
# item: ('04:00:00', 'west-colfax') , 0.004
# item: ('westwood', 'Sunday') , 0.004
# item: ('capitol-hill', 'Sunday') , 0.004
# item: ('Saturday', 'gateway-green-valley-ranch') , 0.004
# item: ('23:59:00', 'hampden') , 0.004
# item: ('stapleton', '23:59:00') , 0.004
# item: ('east-colfax', 'Friday') , 0.005
# item: ('westwood', '16:00:00') , 0.005
# item: ('Sunday', 'gateway-green-valley-ranch') , 0.005
# item: ('east-colfax', '16:00:00') , 0.005
# item: ('23:59:00', 'union-station') , 0.005
# item: ('Wednesday', 'lincoln-park') , 0.005
# item: ('Wednesday', 'west-colfax') , 0.005
# item: ('civic-center', '12:00:00') , 0.005
# item: ('20:00:00', 'stapleton') , 0.005
# item: ('Thursday', 'capitol-hill') , 0.005
# item: ('04:00:00', 'gateway-green-valley-ranch') , 0.005
# item: ('Wednesday', 'capitol-hill') , 0.005
# item: ('east-colfax', 'Tuesday') , 0.005
# item: ('04:00:00', 'cbd') , 0.005
# item: ('capitol-hill', '16:00:00') , 0.005
# item: ('capitol-hill', 'Saturday') , 0.005
# item: ('lincoln-park', 'Friday') , 0.005
# item: ('Sunday', 'union-station') , 0.005
# item: ('lincoln-park', '23:59:00') , 0.005
# item: ('cbd', 'Monday') , 0.005
# item: ('20:00:00', 'lincoln-park') , 0.005
# item: ('Wednesday', 'gateway-green-valley-ranch') , 0.005
# item: ('gateway-green-valley-ranch', 'Tuesday') , 0.005
# item: ('lincoln-park', '16:00:00') , 0.005
# item: ('west-colfax', '23:59:00') , 0.005
# item: ('capitol-hill', 'Monday') , 0.005
# item: ('cbd', 'Tuesday') , 0.005
# item: ('montbello', '12:00:00') , 0.005
# item: ('west-colfax', '16:00:00') , 0.005
# item: ('five-points', '08:00:00') , 0.005
# item: ('capitol-hill', 'Friday') , 0.005
# item: ('Saturday', 'montbello') , 0.005
# item: ('16:00:00', 'gateway-green-valley-ranch') , 0.005
# item: ('union-station', 'Saturday') , 0.005
# item: ('lincoln-park', '12:00:00') , 0.005
# item: ('Friday', 'gateway-green-valley-ranch') , 0.006
# item: ('12:00:00', 'gateway-green-valley-ranch') , 0.006
# item: ('Thursday', 'cbd') , 0.006
# item: ('montbello', 'Tuesday') , 0.006
# item: ('20:00:00', 'union-station') , 0.006
# item: ('Wednesday', 'montbello') , 0.006
# item: ('cbd', 'Saturday') , 0.006
# item: ('Thursday', 'montbello') , 0.006
# item: ('west-colfax', '20:00:00') , 0.006
# item: ('capitol-hill', '12:00:00') , 0.006
# item: ('Sunday', 'montbello') , 0.006
# item: ('04:00:00', 'montbello') , 0.006
# item: ('04:00:00', 'union-station') , 0.006
# item: ('westwood', '23:59:00') , 0.006
# item: ('cbd', 'Friday') , 0.006
# item: ('Monday', 'montbello') , 0.006
# item: ('20:00:00', 'east-colfax') , 0.006
# item: ('20:00:00', 'capitol-hill') , 0.006
# item: ('04:00:00', 'capitol-hill') , 0.006
# item: ('Thursday', 'five-points') , 0.007
# item: ('Wednesday', 'east-colfax') , 0.007
# item: ('23:59:00', 'gateway-green-valley-ranch') , 0.007
# item: ('capitol-hill', '23:59:00') , 0.007
# item: ('montbello', 'Friday') , 0.007
# item: ('cbd', '12:00:00') , 0.007
# item: ('cbd', '16:00:00') , 0.007
# item: ('23:59:00', 'cbd') , 0.007
# item: ('20:00:00', 'gateway-green-valley-ranch') , 0.007
# item: ('20:00:00', 'cbd') , 0.007
# item: ('five-points', 'Tuesday') , 0.007
# item: ('five-points', 'Monday') , 0.008
# item: ('Wednesday', 'five-points') , 0.008
# item: ('five-points', '12:00:00') , 0.008
# item: ('five-points', 'Friday') , 0.008
# item: ('04:00:00', 'five-points') , 0.009
# item: ('16:00:00', 'montbello') , 0.009
# item: ('20:00:00', 'montbello') , 0.009
# item: ('five-points', '16:00:00') , 0.009
# item: ('five-points', 'Saturday') , 0.009
# item: ('23:59:00', 'montbello') , 0.009
# item: ('east-colfax', '23:59:00') , 0.009
# item: ('Sunday', 'five-points') , 0.009
# item: ('08:00:00', 'Saturday') , 0.011
# item: ('08:00:00', 'Tuesday') , 0.011
# item: ('Sunday', '08:00:00') , 0.012
# item: ('Thursday', '08:00:00') , 0.012
# item: ('23:59:00', 'five-points') , 0.013
# item: ('20:00:00', 'five-points') , 0.013
# item: ('08:00:00', 'Friday') , 0.013
# item: ('Wednesday', '08:00:00') , 0.013
# item: ('08:00:00', 'Monday') , 0.013
# item: ('04:00:00', 'Tuesday') , 0.017
# item: ('Thursday', '04:00:00') , 0.018
# item: ('Saturday', '12:00:00') , 0.018
# item: ('Sunday', '12:00:00') , 0.019
# item: ('Wednesday', '04:00:00') , 0.020
# item: ('04:00:00', 'Monday') , 0.020
# item: ('04:00:00', 'Friday') , 0.022
# item: ('12:00:00', 'Tuesday') , 0.022
# item: ('12:00:00', 'Friday') , 0.023
# item: ('Monday', '12:00:00') , 0.023
# item: ('16:00:00', 'Tuesday') , 0.024
# item: ('Thursday', '12:00:00') , 0.024
# item: ('16:00:00', 'Monday') , 0.025
# item: ('Wednesday', '12:00:00') , 0.025
# item: ('Thursday', '16:00:00') , 0.025
# item: ('16:00:00', 'Friday') , 0.026
# item: ('23:59:00', 'Monday') , 0.026
# item: ('20:00:00', 'Sunday') , 0.026
# item: ('Sunday', '16:00:00') , 0.027
# item: ('Wednesday', '16:00:00') , 0.027
# item: ('Wednesday', '23:59:00') , 0.027
# item: ('16:00:00', 'Saturday') , 0.028
# item: ('20:00:00', 'Tuesday') , 0.028
# item: ('04:00:00', 'Saturday') , 0.028
# item: ('23:59:00', 'Tuesday') , 0.028
# item: ('20:00:00', 'Monday') , 0.028
# item: ('Thursday', '20:00:00') , 0.029
# item: ('Thursday', '23:59:00') , 0.030
# item: ('23:59:00', 'Sunday') , 0.030
# item: ('20:00:00', 'Saturday') , 0.030
# item: ('Wednesday', '20:00:00') , 0.032
# item: ('04:00:00', 'Sunday') , 0.032
# item: ('20:00:00', 'Friday') , 0.036
# item: ('23:59:00', 'Saturday') , 0.037
# item: ('23:59:00', 'Friday') , 0.037
#
# ------------------------ RULES:
